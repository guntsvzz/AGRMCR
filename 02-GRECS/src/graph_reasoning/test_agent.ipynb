# %%
from __future__ import absolute_import, division, print_function
import json
from collections import Counter
import os
import argparse
from math import log
from tqdm.auto import tqdm
from easydict import EasyDict as edict
import torch
from functools import reduce
from kg_env_m import BatchKGEnvironment
from actor_critic import ActorCritic
from utils import *
import wandb

class Agrument:
    config = "../../config/beauty/graph_reasoning/UPGPR.json"
    seed = 0 
    set_name = "test_cold_start"
    domain = 'Beauty'
    
args = Agrument() #parser.parse_args()
    
with open(args.config, "r") as f:
    config = edict(json.load(f))

config.processed_data_dir = "../../data/beauty/Amazon_Beauty_01_01"
# Out:
# /Users/guntsv/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
###load_user_pref
def load_user_pref(path, domain):
    user_pref_path = os.path.join(path)
    # Load JSON data from a file
    user_pref = json.load(open(f'{user_pref_path}/user_preference_{domain}.json', 'r'))
    return user_pref


if args.domain is not None:
    user_pref = load_user_pref(config.processed_data_dir, args.domain)

# %%
from make_cold_start_kg import InitalUserEmbedding
if args.set_name in ['test', 'test_cold_start', 'test_cold_start_trim', 'test_cold_start_trim_past_other']:
    set_name = 'test'
    
cold_start_uids = {}

init_embed = InitalUserEmbedding(
    set_name=set_name,
    config=config
)
# Out:
# Load embedding: ../../data/beauty/Amazon_Beauty_01_01/test_transe_embed.pkl

# %%
# embeds  = load_embed(config.processed_data_dir, set_name)
# dataset = load_dataset(config.processed_data_dir, set_name)

for idx in tqdm(range(len(user_pref))):
    user_id = user_pref[str(idx)]['idx_user']
    target_item = user_pref[str(idx)]['idx_item']
    user_acc_feature = user_pref[str(idx)]['user_acc_feature']
    user_rej_feature = user_pref[str(idx)]['user_rej_feature']
    user_rej_items = user_pref[str(idx)]['user_rej_items']
    
    user_preferred = init_embed.user_preference_config(
        user_acc_feature = user_acc_feature, 
        user_rej_feature = user_rej_feature, 
        user_rej_items = user_rej_items, 
    )
    
    user_pref_emb = init_embed.embeds['user'][user_pref[str(idx)]['idx_user']]
    
    idx_cand_user, cand_user_emb = init_embed.distance(user_pref_emb, top_k=6)
    user_preferred['related_user'] = idx_cand_user
    cold_start_uids[user_pref[str(idx)]['idx_user']] = user_preferred
    # break

print('all_user_pref', len(cold_start_uids))
# Out:
#   0%|          | 0/2251 [00:00<?, ?it/s]
# all_user_pref 2079

# %%
# cold_start_uids[867]['non-purchase']

# %%
config.seed = args.seed
config_agent = config.AGENT
config.processed_data_dir = '../../data/beauty/Amazon_Beauty_01_01'

os.environ["CUDA_VISIBLE_DEVICES"] = config_agent.gpu
config_agent.device = torch.device("cuda:0") if torch.cuda.is_available() else "cpu"


if config_agent.early_stopping == True:
    with open("early_stopping.txt", "r") as f:
        config_agent.epochs = int(f.read())

config_agent.log_dir = config.processed_data_dir + "/" + config_agent.name

# %%
####test(config, args.set_name)
set_name = args.set_name
config_agent = config.AGENT
kg_config = config.KG_ARGS

policy_file = config_agent.log_dir + "/tmp_policy_model_epoch_{}.ckpt".format(
    config_agent.epochs
)
if set_name == 'test':
    path_file = config_agent.log_dir + "/policy_paths_epoch_{}.pkl".format(
        config_agent.epochs
    )
elif set_name == 'test_cold_start':
    path_file = config_agent.log_dir + "/policy_paths_epoch_{}_cold_start.pkl".format(
        config_agent.epochs
    )
elif set_name == 'test_cold_start_trim':
    path_file = config_agent.log_dir + "/policy_paths_epoch_{}_cold_start_trim.pkl".format(
        config_agent.epochs
    )
elif set_name == 'test_cold_start_trim_past_other':
    path_file = config_agent.log_dir + "/policy_paths_epoch_{}_cold_start_trim_past_other.pkl".format(
        config_agent.epochs
    )

train_labels = load_labels(config.processed_data_dir, "train")
test_labels = load_labels(config.processed_data_dir, "test")

dataset_name = config.processed_data_dir.split("/")[-1]

train_labels = load_labels(config.processed_data_dir, "train")
test_labels = load_labels(config.processed_data_dir, "test")

dataset_name = config.processed_data_dir.split("/")[-1]

model_name = (
    "UPGPR_len_"
    + str(config_agent.max_path_len)
    + "_"
    + config.AGENT.reward
    + "_"
    + config.TRAIN_EMBEDS.cold_start_embeddings
    + "_mask_"
    + str(config.AGENT.mask_first_interaction)
    + "_max_cold_concept_"
    + str(kg_config.max_nb_cold_entities)
    + "_topk_"
    + "_".join(map(str, config_agent.topk))
)

config_agent.result_file_dir = os.path.join(
    config_agent.result_file_dir, dataset_name, model_name, str(config.seed)
)

os.makedirs(
    config_agent.result_file_dir,
    exist_ok=True,
)

# %%
# if config_agent.run_path:
#     predict_paths(
#         policy_file, 
#         path_file, config, 
#         config_agent, 
#         kg_config
#     )
set_name = 'test'

# %%
from test_agent import batch_beam_search, batch_beam_search_cold_start

print("Predicting paths...")
env = BatchKGEnvironment(
    config.processed_data_dir,
    kg_config,
    set_name=set_name,
    max_acts=config_agent.max_acts,
    max_path_len=config_agent.max_path_len,
    state_history=config_agent.state_history,
    reward_function=config_agent.reward,
    mask_first_interaction=True,
    use_pattern=config_agent.use_pattern,
)
pretrain_sd = torch.load(policy_file, map_location=torch.device("cpu"))
model = ActorCritic(
    env.state_dim,
    env.act_dim,
    gamma=config_agent.gamma,
    hidden_sizes=config_agent.hidden,
    modified_policy=config_agent.modified_policy,
    embed_size=env.embed_size,
).to(config_agent.device)
model_sd = model.state_dict()
model_sd.update(pretrain_sd)
model.load_state_dict(model_sd)

if set_name in ['test', 'test_cold_start', 'test_cold_start_trim', 'test_cold_start_trim_past_other']:
    test_labels = load_labels(config.processed_data_dir, "test")
else:
    test_labels = load_labels(config.processed_data_dir, set_name)
test_uids = list(test_labels.keys())
# Out:
# Predicting paths...
# Orginal kg.G.keys dict_keys(['user', 'item', 'brand', 'category', 'related_product', 'word', 'feature'])
# delete kg.G['feaure']
# Updated kg.G.keys dict_keys(['user', 'item', 'brand', 'category', 'related_product', 'word'])
# Load embedding: ../../data/beauty/Amazon_Beauty_01_01/test_transe_embed.pkl
# Key embed dict_keys(['user', 'item', 'brand', 'category', 'related_product', 'word', 'also_bought', 'also_viewed', 'bought_together', 'described', 'belong_to', 'category_of', 'mentioned', 'interested_in', 'like', 'dislike', 'purchase'])

# %%
# # load cold start users
# cold_users_path = os.path.join(config.processed_data_dir, "cold_start_users.json")
# cold_users = json.load(open(cold_users_path, "r"))

# # load cold start items
# # cold_items_path = os.path.join(config.processed_data_dir, "cold_start_items.json")
# # cold_items = json.load(open(cold_items_path, "r"))

# %%
# Convert lists to sets for fast membership checking
test_uids_set = set(test_uids)
cold_start_set = set(cold_start_uids)
# len(test_uids), len(all_user_pref)
# Extract elements in test_uids but not in all_user_pref
extracted_uids = test_uids_set - cold_start_set
# Convert the result back to a list if needed
non_cold_start_uids = list(extracted_uids)
# len(non_cold_start_uids)
assert len(test_uids) == len(cold_start_uids) + len(non_cold_start_uids)

# %%
len(non_cold_start_uids)
# Out:
# 16228

# %%
batch_size = 16
start_idx = 0
all_paths, all_probs = [], []
pbar = tqdm(total=len(non_cold_start_uids))
# Non-cold start user
while start_idx < len(non_cold_start_uids):
    end_idx = min(start_idx + batch_size, len(non_cold_start_uids))
    batch_uids = non_cold_start_uids[start_idx:end_idx]
    paths, probs = batch_beam_search(
        env,
        model,
        kg_config,
        batch_uids,
        config_agent.device,
        topk=config_agent.topk,
        policy=config_agent.modified_policy,
    )
    all_paths.extend(paths)
    all_probs.extend(probs)
    start_idx = end_idx
    pbar.update(batch_size)
    # break

# Cold start user
def update_paths_with_uid(paths, uid):
    updated_paths = []
    for path in paths:
        updated_path = [(path[0][0], path[0][1], uid)] + path[1:]
        updated_paths.append(updated_path)
    return updated_paths

start_idx = 0
for uid in tqdm(cold_start_uids):
    batch_uids = cold_start_uids[uid]['related_user'][1:]
    paths, probs = batch_beam_search_cold_start(
        env,
        model,
        kg_config,
        batch_uids,
        config_agent.device,
        topk=config_agent.topk,
        policy=config_agent.modified_policy,
        user_pref_embed = user_pref_emb #adding user_pref 
    )

    updated_paths = update_paths_with_uid(paths, uid)
    
    all_paths.extend(updated_paths)
    all_probs.extend(probs)
    # break
    
predicts = {"paths": all_paths, "probs": all_probs}
# pickle.dump(predicts, open(path_file, "wb"))
# if config.use_wandb:
#     wandb.save(path_file)
# Out:
#   0%|          | 0/16228 [00:00<?, ?it/s]
#   0%|          | 0/2079 [00:00<?, ?it/s]

# %%
# len(predicts['paths'])

# %%
# if config_agent.run_eval:
#     evaluate_paths(
#         config.processed_data_dir,
#         path_file,
#         train_labels,
#         test_labels,
#         kg_config,
#         config.use_wandb,
#         config_agent.result_file_dir,
#         validation=False,
#     )

# %%
result_file_dir = config_agent.result_file_dir
dir_path = config.processed_data_dir

embeds = load_embed(dir_path, set_name)
# embeds = load_embed(dir_path, 'train')
user_embeds = embeds["user"]
interaction_embeds = embeds[kg_config.interaction][0]
item_embeds = embeds["item"]
scores = np.dot(user_embeds + interaction_embeds, item_embeds.T)

# 1) Get all valid paths for each user, compute path score and path probability.
results = pickle.load(open(path_file, "rb"))
pred_paths = {uid: {} for uid in test_labels}
# Out:
# Load embedding: ../../data/beauty/Amazon_Beauty_01_01/test_cold_start_transe_embed.pkl

# %%
867 in cold_start_uids.keys()
# Out:
# True

# %%
cold_start_uids[pid]['non-purchase']
# Out:
# [11777,
#  1548,
#  11803,
#  6686,
#  10272,
#  9257,
#  8234,
#  9774,
#  4155,
#  4160,
#  4674,
#  5698,
#  7238,
#  11336,
#  7246,
#  10321,
#  2641,
#  4188,
#  5729,
#  112,
#  10365,
#  10367,
#  7808,
#  3212,
#  10899,
#  4246,
#  11420,
#  3740,
#  668,
#  4767,
#  9888,
#  4257,
#  2722,
#  5796,
#  7343,
#  8890,
#  7872,
#  1217,
#  8396,
#  2766,
#  724,
#  8930,
#  249,
#  10498,
#  7940,
#  3844,
#  6408,
#  3353,
#  10017,
#  7974,
#  9519,
#  2352,
#  10550,
#  10551,
#  9018,
#  5445,
#  4954,
#  3950,
#  9584,
#  6010,
#  7557,
#  7045,
#  2958,
#  6051,
#  5028,
#  1446,
#  10158,
#  5553,
#  438,
#  5047,
#  2493,
#  4543,
#  8143,
#  10194,
#  7637,
#  990,
#  991,
#  4076,
#  9716,
#  4091]

# %%
results
# Out:
# {'paths': [[('self_loop', 'user', 5164),
#    ('like', 'brand', 58),
#    ('belong_to', 'item', 617),
#    ('self_loop', 'item', 617)],
#   [('self_loop', 'user', 5164),
#    ('like', 'brand', 58),
#    ('belong_to', 'item', 2458),
#    ('self_loop', 'item', 2458)],
#   [('self_loop', 'user', 5164),
#    ('mentioned', 'word', 4924),
#    ('described', 'item', 235),
#    ('self_loop', 'item', 235)],
#   [('self_loop', 'user', 5164),
#    ('mentioned', 'word', 4924),
#    ('described', 'item', 1315),
#    ('self_loop', 'item', 1315)],
#   [('self_loop', 'user', 5164),
#    ('dislike', 'brand', 34),
#    ('belong_to', 'item', 2723),
#    ('self_loop', 'item', 2723)],
#   [('self_loop', 'user', 5164),
#    ('dislike', 'brand', 34),
#    ('belong_to', 'item', 167),
#    ('self_loop', 'item', 167)],
#   [('self_loop', 'user', 5164),
#    ('mentioned', 'word', 120),
#    ('described', 'item', 9),
#    ('self_loop', 'item', 9)],
#   [('self_loop', 'user', 5164),
#    ('mentioned', 'word', 120),
#    ('described', 'item', 85),
#    ('self_loop', 'item', 85)],
#   [('self_loop', 'user', 5164),
#    ('interested_in', 'category', 2),
#    ('category_of', 'item', 537),
#    ('self_loop', 'item', 537)],
#   [('self_loop', 'user', 5164),
#    ('interested_in', 'category', 2),
#    ('category_of', 'item', 43),
#    ('self_loop', 'item', 43)],
#   [('self_loop', 'user', 1333),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 72),
#    ('self_loop', 'item', 72)],
#   [('self_loop', 'user', 1333),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 734),
#    ('self_loop', 'item', 734)],
#   [('self_loop', 'user', 1333),
#    ('mentioned', 'word', 620),
#    ('described', 'item', 106),
#    ('self_loop', 'item', 106)],
#   [('self_loop', 'user', 1333),
#    ('mentioned', 'word', 620),
#    ('described', 'item', 72),
#    ('self_loop', 'item', 72)],
#   [('self_loop', 'user', 1333),
#    ('like', 'brand', 533),
#    ('belong_to', 'item', 903),
#    ('self_loop', 'item', 903)],
#   [('self_loop', 'user', 1333),
#    ('like', 'brand', 533),
#    ('self_loop', 'brand', 533),
#    ('belong_to', 'item', 1047)],
#   [('self_loop', 'user', 1333),
#    ('mentioned', 'word', 3730),
#    ('described', 'item', 91),
#    ('self_loop', 'item', 91)],
#   [('self_loop', 'user', 1333),
#    ('mentioned', 'word', 3730),
#    ('described', 'item', 167),
#    ('self_loop', 'item', 167)],
#   [('self_loop', 'user', 1333),
#    ('mentioned', 'word', 8015),
#    ('described', 'item', 195),
#    ('self_loop', 'item', 195)],
#   [('self_loop', 'user', 1333),
#    ('mentioned', 'word', 8015),
#    ('described', 'item', 247),
#    ('self_loop', 'item', 247)],
#   [('self_loop', 'user', 12080),
#    ('interested_in', 'category', 111),
#    ('category_of', 'item', 84),
#    ('self_loop', 'item', 84)],
#   [('self_loop', 'user', 12080),
#    ('interested_in', 'category', 111),
#    ('category_of', 'item', 31),
#    ('self_loop', 'item', 31)],
#   [('self_loop', 'user', 12080),
#    ('like', 'brand', 164),
#    ('belong_to', 'item', 151),
#    ('self_loop', 'item', 151)],
#   [('self_loop', 'user', 12080),
#    ('like', 'brand', 164),
#    ('belong_to', 'item', 278),
#    ('self_loop', 'item', 278)],
#   [('self_loop', 'user', 12080),
#    ('dislike', 'brand', 127),
#    ('belong_to', 'item', 936),
#    ('self_loop', 'item', 936)],
#   [('self_loop', 'user', 12080),
#    ('dislike', 'brand', 127),
#    ('belong_to', 'item', 355),
#    ('self_loop', 'item', 355)],
#   [('self_loop', 'user', 12080),
#    ('dislike', 'brand', 312),
#    ('belong_to', 'item', 755),
#    ('self_loop', 'item', 755)],
#   [('self_loop', 'user', 12080),
#    ('dislike', 'brand', 312),
#    ('belong_to', 'item', 1155),
#    ('self_loop', 'item', 1155)],
#   [('self_loop', 'user', 12080),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 463),
#    ('self_loop', 'item', 463)],
#   [('self_loop', 'user', 12080),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 31),
#    ('self_loop', 'item', 31)],
#   [('self_loop', 'user', 867),
#    ('like', 'brand', 361),
#    ('belong_to', 'item', 1050),
#    ('self_loop', 'item', 1050)],
#   [('self_loop', 'user', 867),
#    ('like', 'brand', 361),
#    ('belong_to', 'item', 608),
#    ('self_loop', 'item', 608)],
#   [('self_loop', 'user', 867),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 987),
#    ('category_of', 'category', 2078)],
#   [('self_loop', 'user', 867),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 815),
#    ('category_of', 'category', 2078)],
#   [('self_loop', 'user', 867),
#    ('like', 'brand', 259),
#    ('dislike', 'user', 8568),
#    ('dislike', 'brand', 399)],
#   [('self_loop', 'user', 867),
#    ('like', 'brand', 259),
#    ('belong_to', 'item', 1429),
#    ('category_of', 'category', 2082)],
#   [('self_loop', 'user', 867),
#    ('interested_in', 'category', 1),
#    ('category_of', 'item', 512),
#    ('self_loop', 'item', 512)],
#   [('self_loop', 'user', 867),
#    ('interested_in', 'category', 1),
#    ('category_of', 'item', 19),
#    ('self_loop', 'item', 19)],
#   [('self_loop', 'user', 867),
#    ('like', 'brand', 41),
#    ('belong_to', 'item', 1135),
#    ('self_loop', 'item', 1135)],
#   [('self_loop', 'user', 867),
#    ('like', 'brand', 41),
#    ('belong_to', 'item', 5764),
#    ('category_of', 'category', 2082)],
#   [('self_loop', 'user', 12887),
#    ('dislike', 'brand', 40),
#    ('belong_to', 'item', 92),
#    ('self_loop', 'item', 92)],
#   [('self_loop', 'user', 12887),
#    ('dislike', 'brand', 40),
#    ('self_loop', 'brand', 40),
#    ('belong_to', 'item', 92)],
#   [('self_loop', 'user', 12887),
#    ('dislike', 'brand', 85),
#    ('belong_to', 'item', 370),
#    ('also_bought', 'related_product', 10373)],
#   [('self_loop', 'user', 12887),
#    ('dislike', 'brand', 85),
#    ('belong_to', 'item', 1114),
#    ('self_loop', 'item', 1114)],
#   [('self_loop', 'user', 12887),
#    ('interested_in', 'category', 59),
#    ('category_of', 'item', 219),
#    ('self_loop', 'item', 219)],
#   [('self_loop', 'user', 12887),
#    ('interested_in', 'category', 59),
#    ('category_of', 'item', 838),
#    ('self_loop', 'item', 838)],
#   [('self_loop', 'user', 12887),
#    ('interested_in', 'category', 153),
#    ('category_of', 'item', 92),
#    ('self_loop', 'item', 92)],
#   [('self_loop', 'user', 12887),
#    ('interested_in', 'category', 153),
#    ('category_of', 'item', 821),
#    ('self_loop', 'item', 821)],
#   [('self_loop', 'user', 12887),
#    ('interested_in', 'category', 38),
#    ('category_of', 'item', 414),
#    ('self_loop', 'item', 414)],
#   [('self_loop', 'user', 12887),
#    ('interested_in', 'category', 38),
#    ('category_of', 'item', 106),
#    ('self_loop', 'item', 106)],
#   [('self_loop', 'user', 3563),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 987),
#    ('category_of', 'category', 2078)],
#   [('self_loop', 'user', 3563),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 21),
#    ('self_loop', 'item', 21)],
#   [('self_loop', 'user', 3563),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 1848),
#    ('self_loop', 'item', 1848)],
#   [('self_loop', 'user', 3563),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 1750),
#    ('self_loop', 'item', 1750)],
#   [('self_loop', 'user', 3563),
#    ('self_loop', 'user', 3563),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 1750)],
#   [('self_loop', 'user', 3563),
#    ('self_loop', 'user', 3563),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 987)],
#   [('self_loop', 'user', 3563),
#    ('interested_in', 'category', 15),
#    ('category_of', 'item', 27),
#    ('self_loop', 'item', 27)],
#   [('self_loop', 'user', 3563),
#    ('interested_in', 'category', 15),
#    ('category_of', 'item', 488),
#    ('self_loop', 'item', 488)],
#   [('self_loop', 'user', 3563),
#    ('like', 'brand', 2),
#    ('belong_to', 'item', 968),
#    ('self_loop', 'item', 968)],
#   [('self_loop', 'user', 3563),
#    ('like', 'brand', 2),
#    ('belong_to', 'item', 2779),
#    ('self_loop', 'item', 2779)],
#   [('self_loop', 'user', 297),
#    ('mentioned', 'word', 1530),
#    ('described', 'item', 1030),
#    ('self_loop', 'item', 1030)],
#   [('self_loop', 'user', 297),
#    ('mentioned', 'word', 1530),
#    ('described', 'item', 1389),
#    ('self_loop', 'item', 1389)],
#   [('self_loop', 'user', 297),
#    ('like', 'brand', 855),
#    ('belong_to', 'item', 1388),
#    ('self_loop', 'item', 1388)],
#   [('self_loop', 'user', 297),
#    ('like', 'brand', 855),
#    ('self_loop', 'brand', 855),
#    ('belong_to', 'item', 1388)],
#   [('self_loop', 'user', 297),
#    ('dislike', 'brand', 841),
#    ('belong_to', 'item', 4039),
#    ('self_loop', 'item', 4039)],
#   [('self_loop', 'user', 297),
#    ('dislike', 'brand', 841),
#    ('self_loop', 'brand', 841),
#    ('belong_to', 'item', 4039)],
#   [('self_loop', 'user', 297),
#    ('mentioned', 'word', 3064),
#    ('described', 'item', 63),
#    ('self_loop', 'item', 63)],
#   [('self_loop', 'user', 297),
#    ('mentioned', 'word', 3064),
#    ('described', 'item', 133),
#    ('self_loop', 'item', 133)],
#   [('self_loop', 'user', 297),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 122),
#    ('self_loop', 'item', 122)],
#   [('self_loop', 'user', 297),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 1193),
#    ('self_loop', 'item', 1193)],
#   [('self_loop', 'user', 22289),
#    ('like', 'brand', 259),
#    ('belong_to', 'item', 839),
#    ('self_loop', 'item', 839)],
#   [('self_loop', 'user', 22289),
#    ('like', 'brand', 259),
#    ('belong_to', 'item', 1506),
#    ('self_loop', 'item', 1506)],
#   [('self_loop', 'user', 22289),
#    ('dislike', 'brand', 287),
#    ('belong_to', 'item', 725),
#    ('self_loop', 'item', 725)],
#   [('self_loop', 'user', 22289),
#    ('dislike', 'brand', 287),
#    ('belong_to', 'item', 566),
#    ('self_loop', 'item', 566)],
#   [('self_loop', 'user', 22289),
#    ('mentioned', 'word', 126),
#    ('described', 'item', 43),
#    ('self_loop', 'item', 43)],
#   [('self_loop', 'user', 22289),
#    ('mentioned', 'word', 126),
#    ('described', 'item', 85),
#    ('self_loop', 'item', 85)],
#   [('self_loop', 'user', 22289),
#    ('mentioned', 'word', 627),
#    ('described', 'item', 161),
#    ('self_loop', 'item', 161)],
#   [('self_loop', 'user', 22289),
#    ('mentioned', 'word', 627),
#    ('described', 'item', 195),
#    ('self_loop', 'item', 195)],
#   [('self_loop', 'user', 22289),
#    ('interested_in', 'category', 143),
#    ('category_of', 'item', 823),
#    ('self_loop', 'item', 823)],
#   [('self_loop', 'user', 22289),
#    ('interested_in', 'category', 143),
#    ('category_of', 'item', 937),
#    ('self_loop', 'item', 937)],
#   [('self_loop', 'user', 6214),
#    ('like', 'brand', 174),
#    ('belong_to', 'item', 51),
#    ('also_bought', 'related_product', 17693)],
#   [('self_loop', 'user', 6214),
#    ('like', 'brand', 174),
#    ('belong_to', 'item', 44),
#    ('self_loop', 'item', 44)],
#   [('self_loop', 'user', 6214),
#    ('interested_in', 'category', 77),
#    ('category_of', 'item', 217),
#    ('self_loop', 'item', 217)],
#   [('self_loop', 'user', 6214),
#    ('interested_in', 'category', 77),
#    ('category_of', 'item', 56),
#    ('self_loop', 'item', 56)],
#   [('self_loop', 'user', 6214),
#    ('mentioned', 'word', 721),
#    ('described', 'item', 314),
#    ('self_loop', 'item', 314)],
#   [('self_loop', 'user', 6214),
#    ('mentioned', 'word', 721),
#    ('described', 'item', 1496),
#    ('self_loop', 'item', 1496)],
#   [('self_loop', 'user', 6214),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 617),
#    ('self_loop', 'item', 617)],
#   [('self_loop', 'user', 6214),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 473),
#    ('self_loop', 'item', 473)],
#   [('self_loop', 'user', 6214),
#    ('mentioned', 'word', 4211),
#    ('described', 'item', 23),
#    ('self_loop', 'item', 23)],
#   [('self_loop', 'user', 6214),
#    ('mentioned', 'word', 4211),
#    ('described', 'item', 161),
#    ('self_loop', 'item', 161)],
#   [('self_loop', 'user', 21576),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 987),
#    ('category_of', 'category', 2078)],
#   [('self_loop', 'user', 21576),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 21),
#    ('self_loop', 'item', 21)],
#   [('self_loop', 'user', 21576),
#    ('like', 'brand', 4),
#    ('belong_to', 'item', 363),
#    ('category_of', 'category', 2124)],
#   [('self_loop', 'user', 21576),
#    ('like', 'brand', 4),
#    ('belong_to', 'item', 96),
#    ('self_loop', 'item', 96)],
#   [('self_loop', 'user', 21576),
#    ('like', 'brand', 245),
#    ('belong_to', 'item', 4926),
#    ('self_loop', 'item', 4926)],
#   [('self_loop', 'user', 21576),
#    ('like', 'brand', 245),
#    ('belong_to', 'item', 5295),
#    ('self_loop', 'item', 5295)],
#   [('self_loop', 'user', 21576),
#    ('like', 'brand', 212),
#    ('belong_to', 'item', 367),
#    ('self_loop', 'item', 367)],
#   [('self_loop', 'user', 21576),
#    ('like', 'brand', 212),
#    ('belong_to', 'item', 152),
#    ('self_loop', 'item', 152)],
#   [('self_loop', 'user', 21576),
#    ('self_loop', 'user', 21576),
#    ('like', 'brand', 4),
#    ('belong_to', 'item', 363)],
#   [('self_loop', 'user', 21576),
#    ('self_loop', 'user', 21576),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 987)],
#   [('self_loop', 'user', 378),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 27),
#    ('self_loop', 'item', 27)],
#   [('self_loop', 'user', 378),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 815),
#    ('category_of', 'category', 2078)],
#   [('self_loop', 'user', 378),
#    ('interested_in', 'category', 46),
#    ('category_of', 'item', 96),
#    ('self_loop', 'item', 96)],
#   [('self_loop', 'user', 378),
#    ('interested_in', 'category', 46),
#    ('self_loop', 'category', 46),
#    ('category_of', 'item', 93)],
#   [('self_loop', 'user', 378),
#    ('like', 'brand', 1742),
#    ('belong_to', 'item', 5630),
#    ('self_loop', 'item', 5630)],
#   [('self_loop', 'user', 378),
#    ('like', 'brand', 1742),
#    ('like', 'user', 1072),
#    ('mentioned', 'word', 2385)],
#   [('self_loop', 'user', 378),
#    ('self_loop', 'user', 378),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 815)],
#   [('self_loop', 'user', 378),
#    ('self_loop', 'user', 378),
#    ('interested_in', 'category', 46),
#    ('category_of', 'item', 96)],
#   [('self_loop', 'user', 378),
#    ('like', 'brand', 4),
#    ('belong_to', 'item', 363),
#    ('self_loop', 'item', 363)],
#   [('self_loop', 'user', 378),
#    ('like', 'brand', 4),
#    ('belong_to', 'item', 96),
#    ('category_of', 'category', 2124)],
#   [('self_loop', 'user', 20047),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 581),
#    ('self_loop', 'item', 581)],
#   [('self_loop', 'user', 20047),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 806),
#    ('self_loop', 'item', 806)],
#   [('self_loop', 'user', 20047),
#    ('like', 'brand', 610),
#    ('belong_to', 'item', 2026),
#    ('self_loop', 'item', 2026)],
#   [('self_loop', 'user', 20047),
#    ('like', 'brand', 610),
#    ('self_loop', 'brand', 610),
#    ('belong_to', 'item', 2026)],
#   [('self_loop', 'user', 20047),
#    ('mentioned', 'word', 644),
#    ('described', 'item', 82),
#    ('self_loop', 'item', 82)],
#   [('self_loop', 'user', 20047),
#    ('mentioned', 'word', 644),
#    ('described', 'item', 1126),
#    ('self_loop', 'item', 1126)],
#   [('self_loop', 'user', 20047),
#    ('mentioned', 'word', 939),
#    ('described', 'item', 35),
#    ('self_loop', 'item', 35)],
#   [('self_loop', 'user', 20047),
#    ('mentioned', 'word', 939),
#    ('described', 'item', 901),
#    ('self_loop', 'item', 901)],
#   [('self_loop', 'user', 20047),
#    ('mentioned', 'word', 1606),
#    ('described', 'item', 137),
#    ('self_loop', 'item', 137)],
#   [('self_loop', 'user', 20047),
#    ('mentioned', 'word', 1606),
#    ('described', 'item', 734),
#    ('self_loop', 'item', 734)],
#   [('self_loop', 'user', 3167),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 62),
#    ('self_loop', 'item', 62)],
#   [('self_loop', 'user', 3167),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 676),
#    ('self_loop', 'item', 676)],
#   [('self_loop', 'user', 3167),
#    ('interested_in', 'category', 74),
#    ('category_of', 'item', 1110),
#    ('self_loop', 'item', 1110)],
#   [('self_loop', 'user', 3167),
#    ('interested_in', 'category', 74),
#    ('category_of', 'item', 65),
#    ('self_loop', 'item', 65)],
#   [('self_loop', 'user', 3167),
#    ('interested_in', 'category', 154),
#    ('category_of', 'item', 6782),
#    ('self_loop', 'item', 6782)],
#   [('self_loop', 'user', 3167),
#    ('interested_in', 'category', 154),
#    ('category_of', 'item', 6452),
#    ('self_loop', 'item', 6452)],
#   [('self_loop', 'user', 3167),
#    ('interested_in', 'category', 1),
#    ('category_of', 'item', 111),
#    ('self_loop', 'item', 111)],
#   [('self_loop', 'user', 3167),
#    ('interested_in', 'category', 1),
#    ('category_of', 'item', 1111),
#    ('self_loop', 'item', 1111)],
#   [('self_loop', 'user', 3167),
#    ('like', 'brand', 10),
#    ('belong_to', 'item', 1802),
#    ('self_loop', 'item', 1802)],
#   [('self_loop', 'user', 3167),
#    ('like', 'brand', 10),
#    ('belong_to', 'item', 1426),
#    ('self_loop', 'item', 1426)],
#   [('self_loop', 'user', 6045),
#    ('like', 'brand', 31),
#    ('belong_to', 'item', 286),
#    ('self_loop', 'item', 286)],
#   [('self_loop', 'user', 6045),
#    ('like', 'brand', 31),
#    ('belong_to', 'item', 106),
#    ('self_loop', 'item', 106)],
#   [('self_loop', 'user', 6045),
#    ('like', 'brand', 385),
#    ('belong_to', 'item', 415),
#    ('self_loop', 'item', 415)],
#   [('self_loop', 'user', 6045),
#    ('like', 'brand', 385),
#    ('belong_to', 'item', 1251),
#    ('self_loop', 'item', 1251)],
#   [('self_loop', 'user', 6045),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 106),
#    ('self_loop', 'item', 106)],
#   [('self_loop', 'user', 6045),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 43),
#    ('self_loop', 'item', 43)],
#   [('self_loop', 'user', 6045),
#    ('mentioned', 'word', 1128),
#    ('described', 'item', 167),
#    ('self_loop', 'item', 167)],
#   [('self_loop', 'user', 6045),
#    ('mentioned', 'word', 1128),
#    ('described', 'item', 367),
#    ('self_loop', 'item', 367)],
#   [('self_loop', 'user', 6045),
#    ('mentioned', 'word', 217),
#    ('described', 'item', 56),
#    ('self_loop', 'item', 56)],
#   [('self_loop', 'user', 6045),
#    ('mentioned', 'word', 217),
#    ('described', 'item', 179),
#    ('self_loop', 'item', 179)],
#   [('self_loop', 'user', 15355),
#    ('interested_in', 'category', 59),
#    ('category_of', 'item', 4329),
#    ('self_loop', 'item', 4329)],
#   [('self_loop', 'user', 15355),
#    ('interested_in', 'category', 59),
#    ('interested_in', 'user', 492),
#    ('interested_in', 'category', 2)],
#   [('self_loop', 'user', 15355),
#    ('like', 'brand', 23),
#    ('belong_to', 'item', 1453),
#    ('self_loop', 'item', 1453)],
#   [('self_loop', 'user', 15355),
#    ('like', 'brand', 23),
#    ('belong_to', 'item', 1062),
#    ('self_loop', 'item', 1062)],
#   [('self_loop', 'user', 15355),
#    ('interested_in', 'category', 32),
#    ('category_of', 'item', 218),
#    ('self_loop', 'item', 218)],
#   [('self_loop', 'user', 15355),
#    ('interested_in', 'category', 32),
#    ('category_of', 'item', 4699),
#    ('self_loop', 'item', 4699)],
#   [('self_loop', 'user', 15355),
#    ('dislike', 'brand', 4),
#    ('belong_to', 'item', 439),
#    ('self_loop', 'item', 439)],
#   [('self_loop', 'user', 15355),
#    ('dislike', 'brand', 4),
#    ('belong_to', 'item', 2644),
#    ('also_bought', 'related_product', 6646)],
#   [('self_loop', 'user', 15355),
#    ('interested_in', 'category', 2),
#    ('category_of', 'item', 161),
#    ('self_loop', 'item', 161)],
#   [('self_loop', 'user', 15355),
#    ('interested_in', 'category', 2),
#    ('category_of', 'item', 43),
#    ('self_loop', 'item', 43)],
#   [('self_loop', 'user', 4492),
#    ('like', 'brand', 4),
#    ('belong_to', 'item', 439),
#    ('self_loop', 'item', 439)],
#   [('self_loop', 'user', 4492),
#    ('like', 'brand', 4),
#    ('belong_to', 'item', 247),
#    ('self_loop', 'item', 247)],
#   [('self_loop', 'user', 4492),
#    ('like', 'brand', 1506),
#    ('belong_to', 'item', 826),
#    ('self_loop', 'item', 826)],
#   [('self_loop', 'user', 4492),
#    ('like', 'brand', 1506),
#    ('belong_to', 'item', 6731),
#    ('self_loop', 'item', 6731)],
#   [('self_loop', 'user', 4492),
#    ('interested_in', 'category', 2),
#    ('category_of', 'item', 65),
#    ('self_loop', 'item', 65)],
#   [('self_loop', 'user', 4492),
#    ('interested_in', 'category', 2),
#    ('category_of', 'item', 15),
#    ('also_bought', 'related_product', 13207)],
#   [('self_loop', 'user', 4492),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 695),
#    ('self_loop', 'item', 695)],
#   [('self_loop', 'user', 4492),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 37),
#    ('self_loop', 'item', 37)],
#   [('self_loop', 'user', 4492),
#    ('interested_in', 'category', 5),
#    ('category_of', 'item', 38),
#    ('self_loop', 'item', 38)],
#   [('self_loop', 'user', 4492),
#    ('interested_in', 'category', 5),
#    ('category_of', 'item', 3),
#    ('self_loop', 'item', 3)],
#   [('self_loop', 'user', 12566),
#    ('mentioned', 'word', 1779),
#    ('described', 'item', 436),
#    ('self_loop', 'item', 436)],
#   [('self_loop', 'user', 12566),
#    ('mentioned', 'word', 1779),
#    ('described', 'item', 2673),
#    ('self_loop', 'item', 2673)],
#   [('self_loop', 'user', 12566),
#    ('mentioned', 'word', 120),
#    ('described', 'item', 23),
#    ('self_loop', 'item', 23)],
#   [('self_loop', 'user', 12566),
#    ('mentioned', 'word', 120),
#    ('described', 'item', 106),
#    ('self_loop', 'item', 106)],
#   [('self_loop', 'user', 12566),
#    ('mentioned', 'word', 1496),
#    ('described', 'item', 132),
#    ('self_loop', 'item', 132)],
#   [('self_loop', 'user', 12566),
#    ('mentioned', 'word', 1496),
#    ('described', 'item', 320),
#    ('self_loop', 'item', 320)],
#   [('self_loop', 'user', 12566),
#    ('mentioned', 'word', 1911),
#    ('described', 'item', 124),
#    ('self_loop', 'item', 124)],
#   [('self_loop', 'user', 12566),
#    ('mentioned', 'word', 1911),
#    ('described', 'item', 1313),
#    ('self_loop', 'item', 1313)],
#   [('self_loop', 'user', 12566),
#    ('mentioned', 'word', 2208),
#    ('described', 'item', 245),
#    ('self_loop', 'item', 245)],
#   [('self_loop', 'user', 12566),
#    ('mentioned', 'word', 2208),
#    ('described', 'item', 3249),
#    ('self_loop', 'item', 3249)],
#   [('self_loop', 'user', 12757),
#    ('interested_in', 'category', 63),
#    ('category_of', 'item', 1076),
#    ('self_loop', 'item', 1076)],
#   [('self_loop', 'user', 12757),
#    ('interested_in', 'category', 63),
#    ('category_of', 'item', 581),
#    ('self_loop', 'item', 581)],
#   [('self_loop', 'user', 12757),
#    ('like', 'brand', 1307),
#    ('belong_to', 'item', 6856),
#    ('self_loop', 'item', 6856)],
#   [('self_loop', 'user', 12757),
#    ('like', 'brand', 1307),
#    ('self_loop', 'brand', 1307),
#    ('belong_to', 'item', 6856)],
#   [('self_loop', 'user', 12757),
#    ('interested_in', 'category', 59),
#    ('category_of', 'item', 81),
#    ('self_loop', 'item', 81)],
#   [('self_loop', 'user', 12757),
#    ('interested_in', 'category', 59),
#    ('category_of', 'item', 36),
#    ('self_loop', 'item', 36)],
#   [('self_loop', 'user', 12757),
#    ('mentioned', 'word', 495),
#    ('described', 'item', 161),
#    ('self_loop', 'item', 161)],
#   [('self_loop', 'user', 12757),
#    ('mentioned', 'word', 495),
#    ('described', 'item', 921),
#    ('self_loop', 'item', 921)],
#   [('self_loop', 'user', 12757),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 728),
#    ('self_loop', 'item', 728)],
#   [('self_loop', 'user', 12757),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 107),
#    ('self_loop', 'item', 107)],
#   [('self_loop', 'user', 21991),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 21),
#    ('self_loop', 'item', 21)],
#   [('self_loop', 'user', 21991),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 815),
#    ('category_of', 'category', 2078)],
#   [('self_loop', 'user', 21991),
#    ('interested_in', 'category', 2),
#    ('category_of', 'item', 102),
#    ('category_of', 'category', 2078)],
#   [('self_loop', 'user', 21991),
#    ('interested_in', 'category', 2),
#    ('category_of', 'item', 43),
#    ('self_loop', 'item', 43)],
#   [('self_loop', 'user', 21991),
#    ('like', 'brand', 1485),
#    ('belong_to', 'item', 4865),
#    ('self_loop', 'item', 4865)],
#   [('self_loop', 'user', 21991),
#    ('like', 'brand', 1485),
#    ('self_loop', 'brand', 1485),
#    ('belong_to', 'item', 4865)],
#   [('self_loop', 'user', 21991),
#    ('interested_in', 'category', 15),
#    ('category_of', 'item', 27),
#    ('self_loop', 'item', 27)],
#   [('self_loop', 'user', 21991),
#    ('interested_in', 'category', 15),
#    ('category_of', 'item', 21),
#    ('category_of', 'category', 2078)],
#   [('self_loop', 'user', 21991),
#    ('interested_in', 'category', 29),
#    ('category_of', 'item', 126),
#    ('self_loop', 'item', 126)],
#   [('self_loop', 'user', 21991),
#    ('interested_in', 'category', 29),
#    ('category_of', 'item', 705),
#    ('self_loop', 'item', 705)],
#   [('self_loop', 'user', 3012),
#    ('mentioned', 'word', 1130),
#    ('described', 'item', 99),
#    ('self_loop', 'item', 99)],
#   [('self_loop', 'user', 3012),
#    ('mentioned', 'word', 1130),
#    ('described', 'item', 1144),
#    ('self_loop', 'item', 1144)],
#   [('self_loop', 'user', 3012),
#    ('like', 'brand', 1778),
#    ('belong_to', 'item', 5301),
#    ('self_loop', 'item', 5301)],
#   [('self_loop', 'user', 3012),
#    ('like', 'brand', 1778),
#    ('belong_to', 'item', 3349),
#    ('self_loop', 'item', 3349)],
#   [('self_loop', 'user', 3012),
#    ('mentioned', 'word', 2970),
#    ('described', 'item', 295),
#    ('self_loop', 'item', 295)],
#   [('self_loop', 'user', 3012),
#    ('mentioned', 'word', 2970),
#    ('described', 'item', 9224),
#    ('self_loop', 'item', 9224)],
#   [('self_loop', 'user', 3012),
#    ('interested_in', 'category', 46),
#    ('category_of', 'item', 23),
#    ('self_loop', 'item', 23)],
#   [('self_loop', 'user', 3012),
#    ('interested_in', 'category', 46),
#    ('category_of', 'item', 530),
#    ('self_loop', 'item', 530)],
#   [('self_loop', 'user', 3012),
#    ('interested_in', 'category', 100),
#    ('category_of', 'item', 99),
#    ('self_loop', 'item', 99)],
#   [('self_loop', 'user', 3012),
#    ('interested_in', 'category', 100),
#    ('category_of', 'item', 11),
#    ('self_loop', 'item', 11)],
#   [('self_loop', 'user', 5373),
#    ('dislike', 'brand', 805),
#    ('belong_to', 'item', 93),
#    ('self_loop', 'item', 93)],
#   [('self_loop', 'user', 5373),
#    ('dislike', 'brand', 805),
#    ('belong_to', 'item', 1981),
#    ('self_loop', 'item', 1981)],
#   [('self_loop', 'user', 5373),
#    ('interested_in', 'category', 55),
#    ('category_of', 'item', 23),
#    ('self_loop', 'item', 23)],
#   [('self_loop', 'user', 5373),
#    ('interested_in', 'category', 55),
#    ('category_of', 'item', 7),
#    ('self_loop', 'item', 7)],
#   [('self_loop', 'user', 5373),
#    ('interested_in', 'category', 61),
#    ('category_of', 'item', 369),
#    ('self_loop', 'item', 369)],
#   [('self_loop', 'user', 5373),
#    ('interested_in', 'category', 61),
#    ('category_of', 'item', 85),
#    ('self_loop', 'item', 85)],
#   [('self_loop', 'user', 5373),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 9),
#    ('self_loop', 'item', 9)],
#   [('self_loop', 'user', 5373),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 7),
#    ('self_loop', 'item', 7)],
#   [('self_loop', 'user', 5373),
#    ('interested_in', 'category', 1),
#    ('category_of', 'item', 43),
#    ('self_loop', 'item', 43)],
#   [('self_loop', 'user', 5373),
#    ('interested_in', 'category', 1),
#    ('category_of', 'item', 9),
#    ('self_loop', 'item', 9)],
#   [('self_loop', 'user', 4248),
#    ('mentioned', 'word', 1081),
#    ('described', 'item', 316),
#    ('self_loop', 'item', 316)],
#   [('self_loop', 'user', 4248),
#    ('mentioned', 'word', 1081),
#    ('described', 'item', 384),
#    ('self_loop', 'item', 384)],
#   [('self_loop', 'user', 4248),
#    ('mentioned', 'word', 1510),
#    ('described', 'item', 1019),
#    ('self_loop', 'item', 1019)],
#   [('self_loop', 'user', 4248),
#    ('mentioned', 'word', 1510),
#    ('described', 'item', 1336),
#    ('self_loop', 'item', 1336)],
#   [('self_loop', 'user', 4248),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 502),
#    ('self_loop', 'item', 502)],
#   [('self_loop', 'user', 4248),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 25),
#    ('self_loop', 'item', 25)],
#   [('self_loop', 'user', 4248),
#    ('mentioned', 'word', 1319),
#    ('described', 'item', 367),
#    ('self_loop', 'item', 367)],
#   [('self_loop', 'user', 4248),
#    ('mentioned', 'word', 1319),
#    ('described', 'item', 1084),
#    ('self_loop', 'item', 1084)],
#   [('self_loop', 'user', 4248),
#    ('interested_in', 'category', 11),
#    ('category_of', 'item', 1327),
#    ('self_loop', 'item', 1327)],
#   [('self_loop', 'user', 4248),
#    ('interested_in', 'category', 11),
#    ('category_of', 'item', 1172),
#    ('self_loop', 'item', 1172)],
#   [('self_loop', 'user', 1259),
#    ('interested_in', 'category', 243),
#    ('category_of', 'item', 4433),
#    ('self_loop', 'item', 4433)],
#   [('self_loop', 'user', 1259),
#    ('interested_in', 'category', 243),
#    ('category_of', 'item', 2852),
#    ('self_loop', 'item', 2852)],
#   [('self_loop', 'user', 1259),
#    ('like', 'brand', 963),
#    ('belong_to', 'item', 6191),
#    ('self_loop', 'item', 6191)],
#   [('self_loop', 'user', 1259),
#    ('like', 'brand', 963),
#    ('belong_to', 'item', 476),
#    ('self_loop', 'item', 476)],
#   [('self_loop', 'user', 1259),
#    ('dislike', 'brand', 494),
#    ('belong_to', 'item', 313),
#    ('self_loop', 'item', 313)],
#   [('self_loop', 'user', 1259),
#    ('dislike', 'brand', 494),
#    ('belong_to', 'item', 1010),
#    ('self_loop', 'item', 1010)],
#   [('self_loop', 'user', 1259),
#    ('mentioned', 'word', 435),
#    ('described', 'item', 358),
#    ('self_loop', 'item', 358)],
#   [('self_loop', 'user', 1259),
#    ('mentioned', 'word', 435),
#    ('described', 'item', 362),
#    ('self_loop', 'item', 362)],
#   [('self_loop', 'user', 1259),
#    ('mentioned', 'word', 964),
#    ('described', 'item', 37),
#    ('self_loop', 'item', 37)],
#   [('self_loop', 'user', 1259),
#    ('mentioned', 'word', 964),
#    ('described', 'item', 247),
#    ('described', 'word', 997)],
#   [('self_loop', 'user', 4598),
#    ('like', 'brand', 57),
#    ('belong_to', 'item', 963),
#    ('self_loop', 'item', 963)],
#   [('self_loop', 'user', 4598),
#    ('like', 'brand', 57),
#    ('belong_to', 'item', 750),
#    ('self_loop', 'item', 750)],
#   [('self_loop', 'user', 4598),
#    ('like', 'brand', 559),
#    ('belong_to', 'item', 1228),
#    ('self_loop', 'item', 1228)],
#   [('self_loop', 'user', 4598),
#    ('like', 'brand', 559),
#    ('belong_to', 'item', 165),
#    ('self_loop', 'item', 165)],
#   [('self_loop', 'user', 4598),
#    ('mentioned', 'word', 701),
#    ('described', 'item', 1251),
#    ('self_loop', 'item', 1251)],
#   [('self_loop', 'user', 4598),
#    ('mentioned', 'word', 701),
#    ('described', 'item', 381),
#    ('self_loop', 'item', 381)],
#   [('self_loop', 'user', 4598),
#    ('like', 'brand', 4),
#    ('belong_to', 'item', 195),
#    ('self_loop', 'item', 195)],
#   [('self_loop', 'user', 4598),
#    ('like', 'brand', 4),
#    ('belong_to', 'item', 3809),
#    ('self_loop', 'item', 3809)],
#   [('self_loop', 'user', 4598),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 502),
#    ('self_loop', 'item', 502)],
#   [('self_loop', 'user', 4598),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 546),
#    ('self_loop', 'item', 546)],
#   [('self_loop', 'user', 7562),
#    ('mentioned', 'word', 2984),
#    ('described', 'item', 111),
#    ('self_loop', 'item', 111)],
#   [('self_loop', 'user', 7562),
#    ('mentioned', 'word', 2984),
#    ('described', 'item', 100),
#    ('self_loop', 'item', 100)],
#   [('self_loop', 'user', 7562),
#    ('mentioned', 'word', 3293),
#    ('described', 'item', 827),
#    ('described', 'word', 74)],
#   [('self_loop', 'user', 7562),
#    ('mentioned', 'word', 3293),
#    ('described', 'item', 1019),
#    ('described', 'word', 14)],
#   [('self_loop', 'user', 7562),
#    ('interested_in', 'category', 1),
#    ('category_of', 'item', 253),
#    ('self_loop', 'item', 253)],
#   [('self_loop', 'user', 7562),
#    ('interested_in', 'category', 1),
#    ('category_of', 'item', 43),
#    ('self_loop', 'item', 43)],
#   [('self_loop', 'user', 7562),
#    ('interested_in', 'category', 46),
#    ('category_of', 'item', 6),
#    ('self_loop', 'item', 6)],
#   [('self_loop', 'user', 7562),
#    ('interested_in', 'category', 46),
#    ('category_of', 'item', 5),
#    ('self_loop', 'item', 5)],
#   [('self_loop', 'user', 7562),
#    ('interested_in', 'category', 100),
#    ('category_of', 'item', 6),
#    ('self_loop', 'item', 6)],
#   [('self_loop', 'user', 7562),
#    ('interested_in', 'category', 100),
#    ('category_of', 'item', 5),
#    ('self_loop', 'item', 5)],
#   [('self_loop', 'user', 14357),
#    ('interested_in', 'category', 124),
#    ('category_of', 'item', 482),
#    ('self_loop', 'item', 482)],
#   [('self_loop', 'user', 14357),
#    ('interested_in', 'category', 124),
#    ('category_of', 'item', 23),
#    ('self_loop', 'item', 23)],
#   [('self_loop', 'user', 14357),
#    ('dislike', 'brand', 4),
#    ('belong_to', 'item', 247),
#    ('self_loop', 'item', 247)],
#   [('self_loop', 'user', 14357),
#    ('dislike', 'brand', 4),
#    ('belong_to', 'item', 195),
#    ('self_loop', 'item', 195)],
#   [('self_loop', 'user', 14357),
#    ('mentioned', 'word', 1063),
#    ('described', 'item', 442),
#    ('self_loop', 'item', 442)],
#   [('self_loop', 'user', 14357),
#    ('mentioned', 'word', 1063),
#    ('described', 'item', 328),
#    ('self_loop', 'item', 328)],
#   [('self_loop', 'user', 14357),
#    ('interested_in', 'category', 46),
#    ('category_of', 'item', 200),
#    ('self_loop', 'item', 200)],
#   [('self_loop', 'user', 14357),
#    ('interested_in', 'category', 46),
#    ('category_of', 'item', 1387),
#    ('self_loop', 'item', 1387)],
#   [('self_loop', 'user', 14357),
#    ('mentioned', 'word', 114),
#    ('described', 'item', 412),
#    ('self_loop', 'item', 412)],
#   [('self_loop', 'user', 14357),
#    ('mentioned', 'word', 114),
#    ('described', 'item', 381),
#    ('self_loop', 'item', 381)],
#   [('self_loop', 'user', 1749),
#    ('interested_in', 'category', 75),
#    ('category_of', 'item', 65),
#    ('self_loop', 'item', 65)],
#   [('self_loop', 'user', 1749),
#    ('interested_in', 'category', 75),
#    ('category_of', 'item', 684),
#    ('self_loop', 'item', 684)],
#   [('self_loop', 'user', 1749),
#    ('like', 'brand', 54),
#    ('belong_to', 'item', 218),
#    ('self_loop', 'item', 218)],
#   [('self_loop', 'user', 1749),
#    ('like', 'brand', 54),
#    ('belong_to', 'item', 328),
#    ('self_loop', 'item', 328)],
#   [('self_loop', 'user', 1749),
#    ('like', 'brand', 272),
#    ('belong_to', 'item', 7233),
#    ('self_loop', 'item', 7233)],
#   [('self_loop', 'user', 1749),
#    ('like', 'brand', 272),
#    ('dislike', 'user', 597),
#    ('interested_in', 'category', 0)],
#   [('self_loop', 'user', 1749),
#    ('dislike', 'brand', 986),
#    ('belong_to', 'item', 577),
#    ('self_loop', 'item', 577)],
#   [('self_loop', 'user', 1749),
#    ('dislike', 'brand', 986),
#    ('belong_to', 'item', 837),
#    ('self_loop', 'item', 837)],
#   [('self_loop', 'user', 1749),
#    ('interested_in', 'category', 37),
#    ('category_of', 'item', 577),
#    ('self_loop', 'item', 577)],
#   [('self_loop', 'user', 1749),
#    ('interested_in', 'category', 37),
#    ('category_of', 'item', 2905),
#    ('self_loop', 'item', 2905)],
#   [('self_loop', 'user', 2189),
#    ('mentioned', 'word', 511),
#    ('described', 'item', 85),
#    ('self_loop', 'item', 85)],
#   [('self_loop', 'user', 2189),
#    ('mentioned', 'word', 511),
#    ('described', 'item', 111),
#    ('self_loop', 'item', 111)],
#   [('self_loop', 'user', 2189),
#    ('mentioned', 'word', 231),
#    ('described', 'item', 43),
#    ('self_loop', 'item', 43)],
#   [('self_loop', 'user', 2189),
#    ('mentioned', 'word', 231),
#    ('described', 'item', 72),
#    ('also_bought', 'related_product', 103086)],
#   [('self_loop', 'user', 2189),
#    ('mentioned', 'word', 628),
#    ('described', 'item', 2046),
#    ('self_loop', 'item', 2046)],
#   [('self_loop', 'user', 2189),
#    ('mentioned', 'word', 628),
#    ('described', 'item', 2690),
#    ('self_loop', 'item', 2690)],
#   [('self_loop', 'user', 2189),
#    ('mentioned', 'word', 1220),
#    ('described', 'item', 381),
#    ('self_loop', 'item', 381)],
#   [('self_loop', 'user', 2189),
#    ('mentioned', 'word', 1220),
#    ('described', 'item', 8293),
#    ('self_loop', 'item', 8293)],
#   [('self_loop', 'user', 2189),
#    ('mentioned', 'word', 1275),
#    ('described', 'item', 1042),
#    ('self_loop', 'item', 1042)],
#   [('self_loop', 'user', 2189),
#    ('mentioned', 'word', 1275),
#    ('described', 'item', 161),
#    ('self_loop', 'item', 161)],
#   [('self_loop', 'user', 16766),
#    ('like', 'brand', 514),
#    ('belong_to', 'item', 1406),
#    ('self_loop', 'item', 1406)],
#   [('self_loop', 'user', 16766),
#    ('like', 'brand', 514),
#    ('self_loop', 'brand', 514),
#    ('belong_to', 'item', 1406)],
#   [('self_loop', 'user', 16766),
#    ('interested_in', 'category', 162),
#    ('category_of', 'item', 971),
#    ('self_loop', 'item', 971)],
#   [('self_loop', 'user', 16766),
#    ('interested_in', 'category', 162),
#    ('category_of', 'item', 676),
#    ('self_loop', 'item', 676)],
#   [('self_loop', 'user', 16766),
#    ('mentioned', 'word', 669),
#    ('described', 'item', 124),
#    ('self_loop', 'item', 124)],
#   [('self_loop', 'user', 16766),
#    ('mentioned', 'word', 669),
#    ('described', 'item', 118),
#    ('self_loop', 'item', 118)],
#   [('self_loop', 'user', 16766),
#    ('mentioned', 'word', 1440),
#    ('described', 'item', 43),
#    ('self_loop', 'item', 43)],
#   [('self_loop', 'user', 16766),
#    ('mentioned', 'word', 1440),
#    ('described', 'item', 3),
#    ('self_loop', 'item', 3)],
#   [('self_loop', 'user', 16766),
#    ('dislike', 'brand', 1623),
#    ('belong_to', 'item', 3053),
#    ('self_loop', 'item', 3053)],
#   [('self_loop', 'user', 16766),
#    ('dislike', 'brand', 1623),
#    ('self_loop', 'brand', 1623),
#    ('belong_to', 'item', 3053)],
#   [('self_loop', 'user', 18384),
#    ('like', 'brand', 412),
#    ('belong_to', 'item', 322),
#    ('self_loop', 'item', 322)],
#   [('self_loop', 'user', 18384),
#    ('like', 'brand', 412),
#    ('belong_to', 'item', 419),
#    ('self_loop', 'item', 419)],
#   [('self_loop', 'user', 18384),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 56),
#    ('self_loop', 'item', 56)],
#   [('self_loop', 'user', 18384),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 572),
#    ('self_loop', 'item', 572)],
#   [('self_loop', 'user', 18384),
#    ('mentioned', 'word', 664),
#    ('described', 'item', 412),
#    ('self_loop', 'item', 412)],
#   [('self_loop', 'user', 18384),
#    ('mentioned', 'word', 664),
#    ('described', 'item', 43),
#    ('self_loop', 'item', 43)],
#   [('self_loop', 'user', 18384),
#    ('like', 'brand', 4),
#    ('belong_to', 'item', 35),
#    ('self_loop', 'item', 35)],
#   [('self_loop', 'user', 18384),
#    ('like', 'brand', 4),
#    ('belong_to', 'item', 22),
#    ('self_loop', 'item', 22)],
#   [('self_loop', 'user', 18384),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 22),
#    ('self_loop', 'item', 22)],
#   [('self_loop', 'user', 18384),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 436),
#    ('self_loop', 'item', 436)],
#   [('self_loop', 'user', 1005),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 439),
#    ('self_loop', 'item', 439)],
#   [('self_loop', 'user', 1005),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 488),
#    ('self_loop', 'item', 488)],
#   [('self_loop', 'user', 1005),
#    ('mentioned', 'word', 4040),
#    ('described', 'item', 156),
#    ('self_loop', 'item', 156)],
#   [('self_loop', 'user', 1005),
#    ('mentioned', 'word', 4040),
#    ('described', 'item', 186),
#    ('also_viewed', 'related_product', 152896)],
#   [('self_loop', 'user', 1005),
#    ('mentioned', 'word', 1936),
#    ('described', 'item', 72),
#    ('self_loop', 'item', 72)],
#   [('self_loop', 'user', 1005),
#    ('mentioned', 'word', 1936),
#    ('described', 'item', 36),
#    ('self_loop', 'item', 36)],
#   [('self_loop', 'user', 1005),
#    ('mentioned', 'word', 1479),
#    ('described', 'item', 55),
#    ('self_loop', 'item', 55)],
#   [('self_loop', 'user', 1005),
#    ('mentioned', 'word', 1479),
#    ('described', 'item', 285),
#    ('self_loop', 'item', 285)],
#   [('self_loop', 'user', 1005),
#    ('mentioned', 'word', 4768),
#    ('described', 'item', 36),
#    ('self_loop', 'item', 36)],
#   [('self_loop', 'user', 1005),
#    ('mentioned', 'word', 4768),
#    ('described', 'item', 55),
#    ('self_loop', 'item', 55)],
#   [('self_loop', 'user', 20135),
#    ('like', 'brand', 1558),
#    ('belong_to', 'item', 2043),
#    ('self_loop', 'item', 2043)],
#   [('self_loop', 'user', 20135),
#    ('like', 'brand', 1558),
#    ('belong_to', 'item', 1017),
#    ('self_loop', 'item', 1017)],
#   [('self_loop', 'user', 20135),
#    ('mentioned', 'word', 2535),
#    ('described', 'item', 194),
#    ('self_loop', 'item', 194)],
#   [('self_loop', 'user', 20135),
#    ('mentioned', 'word', 2535),
#    ('described', 'item', 1368),
#    ('self_loop', 'item', 1368)],
#   [('self_loop', 'user', 20135),
#    ('like', 'brand', 109),
#    ('belong_to', 'item', 3764),
#    ('self_loop', 'item', 3764)],
#   [('self_loop', 'user', 20135),
#    ('like', 'brand', 109),
#    ('belong_to', 'item', 1684),
#    ('self_loop', 'item', 1684)],
#   [('self_loop', 'user', 20135),
#    ('mentioned', 'word', 3922),
#    ('described', 'item', 247),
#    ('self_loop', 'item', 247)],
#   [('self_loop', 'user', 20135),
#    ('mentioned', 'word', 3922),
#    ('described', 'item', 235),
#    ('self_loop', 'item', 235)],
#   [('self_loop', 'user', 20135),
#    ('interested_in', 'category', 27),
#    ('category_of', 'item', 56),
#    ('self_loop', 'item', 56)],
#   [('self_loop', 'user', 20135),
#    ('interested_in', 'category', 27),
#    ('category_of', 'item', 88),
#    ('self_loop', 'item', 88)],
#   [('self_loop', 'user', 9841),
#    ('interested_in', 'category', 64),
#    ('category_of', 'item', 1240),
#    ('self_loop', 'item', 1240)],
#   [('self_loop', 'user', 9841),
#    ('interested_in', 'category', 64),
#    ('category_of', 'item', 5655),
#    ('self_loop', 'item', 5655)],
#   [('self_loop', 'user', 9841),
#    ('interested_in', 'category', 225),
#    ('category_of', 'item', 2112),
#    ('category_of', 'category', 2078)],
#   [('self_loop', 'user', 9841),
#    ('interested_in', 'category', 225),
#    ('category_of', 'item', 2075),
#    ('self_loop', 'item', 2075)],
#   [('self_loop', 'user', 9841),
#    ('like', 'brand', 259),
#    ('belong_to', 'item', 1506),
#    ('self_loop', 'item', 1506)],
#   [('self_loop', 'user', 9841),
#    ('like', 'brand', 259),
#    ('belong_to', 'item', 3489),
#    ('self_loop', 'item', 3489)],
#   [('self_loop', 'user', 9841),
#    ('like', 'brand', 2038),
#    ('dislike', 'user', 9987),
#    ('like', 'brand', 656)],
#   [('self_loop', 'user', 9841),
#    ('like', 'brand', 2038),
#    ('dislike', 'user', 13332),
#    ('dislike', 'brand', 1988)],
#   [('self_loop', 'user', 9841),
#    ('like', 'brand', 1371),
#    ('belong_to', 'item', 456),
#    ('self_loop', 'item', 456)],
#   [('self_loop', 'user', 9841),
#    ('like', 'brand', 1371),
#    ('belong_to', 'item', 3181),
#    ('self_loop', 'item', 3181)],
#   [('self_loop', 'user', 12552),
#    ('dislike', 'brand', 4),
#    ('belong_to', 'item', 439),
#    ('self_loop', 'item', 439)],
#   [('self_loop', 'user', 12552),
#    ('dislike', 'brand', 4),
#    ('belong_to', 'item', 247),
#    ('self_loop', 'item', 247)],
#   [('self_loop', 'user', 12552),
#    ('mentioned', 'word', 4365),
#    ('described', 'item', 1199),
#    ('self_loop', 'item', 1199)],
#   [('self_loop', 'user', 12552),
#    ('mentioned', 'word', 4365),
#    ('described', 'item', 1455),
#    ('self_loop', 'item', 1455)],
#   [('self_loop', 'user', 12552),
#    ('mentioned', 'word', 2021),
#    ('described', 'item', 195),
#    ('self_loop', 'item', 195)],
#   [('self_loop', 'user', 12552),
#    ('mentioned', 'word', 2021),
#    ('described', 'item', 286),
#    ('also_bought', 'related_product', 19463)],
#   [('self_loop', 'user', 12552),
#    ('mentioned', 'word', 8614),
#    ('described', 'item', 55),
#    ('self_loop', 'item', 55)],
#   [('self_loop', 'user', 12552),
#    ('mentioned', 'word', 8614),
#    ('described', 'item', 1318),
#    ('self_loop', 'item', 1318)],
#   [('self_loop', 'user', 12552),
#    ('mentioned', 'word', 10197),
#    ('described', 'item', 197),
#    ('self_loop', 'item', 197)],
#   [('self_loop', 'user', 12552),
#    ('mentioned', 'word', 10197),
#    ('described', 'item', 51),
#    ('self_loop', 'item', 51)],
#   [('self_loop', 'user', 7344),
#    ('mentioned', 'word', 982),
#    ('described', 'item', 186),
#    ('self_loop', 'item', 186)],
#   [('self_loop', 'user', 7344),
#    ('mentioned', 'word', 982),
#    ('described', 'item', 751),
#    ('self_loop', 'item', 751)],
#   [('self_loop', 'user', 7344),
#    ('mentioned', 'word', 2960),
#    ('described', 'item', 3227),
#    ('self_loop', 'item', 3227)],
#   [('self_loop', 'user', 7344),
#    ('mentioned', 'word', 2960),
#    ('described', 'item', 2743),
#    ('described', 'word', 141)],
#   [('self_loop', 'user', 7344),
#    ('mentioned', 'word', 3914),
#    ('described', 'item', 1540),
#    ('self_loop', 'item', 1540)],
#   [('self_loop', 'user', 7344),
#    ('mentioned', 'word', 3914),
#    ('described', 'item', 1389),
#    ('self_loop', 'item', 1389)],
#   [('self_loop', 'user', 7344),
#    ('like', 'brand', 537),
#    ('belong_to', 'item', 472),
#    ('self_loop', 'item', 472)],
#   [('self_loop', 'user', 7344),
#    ('like', 'brand', 537),
#    ('belong_to', 'item', 190),
#    ('self_loop', 'item', 190)],
#   [('self_loop', 'user', 7344),
#    ('dislike', 'brand', 119),
#    ('belong_to', 'item', 430),
#    ('self_loop', 'item', 430)],
#   [('self_loop', 'user', 7344),
#    ('dislike', 'brand', 119),
#    ('belong_to', 'item', 779),
#    ('self_loop', 'item', 779)],
#   [('self_loop', 'user', 1063),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 27),
#    ('self_loop', 'item', 27)],
#   [('self_loop', 'user', 1063),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 801),
#    ('self_loop', 'item', 801)],
#   [('self_loop', 'user', 1063),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 41),
#    ('self_loop', 'item', 41)],
#   [('self_loop', 'user', 1063),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 2121),
#    ('self_loop', 'item', 2121)],
#   [('self_loop', 'user', 1063),
#    ('self_loop', 'user', 1063),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 801)],
#   [('self_loop', 'user', 1063),
#    ('self_loop', 'user', 1063),
#    ('interested_in', 'category', 4),
#    ('category_of', 'item', 2171)],
#   [('self_loop', 'user', 1063),
#    ('interested_in', 'category', 5),
#    ('category_of', 'item', 319),
#    ('self_loop', 'item', 319)],
#   [('self_loop', 'user', 1063),
#    ('interested_in', 'category', 5),
#    ('category_of', 'item', 244),
#    ('self_loop', 'item', 244)],
#   [('self_loop', 'user', 1063),
#    ('interested_in', 'category', 15),
#    ('category_of', 'item', 27),
#    ('category_of', 'category', 2078)],
#   [('self_loop', 'user', 1063),
#    ('interested_in', 'category', 15),
#    ('category_of', 'item', 21),
#    ('self_loop', 'item', 21)],
#   [('self_loop', 'user', 3645),
#    ('interested_in', 'category', 31),
#    ('category_of', 'item', 916),
#    ('self_loop', 'item', 916)],
#   [('self_loop', 'user', 3645),
#    ('interested_in', 'category', 31),
#    ('category_of', 'item', 824),
#    ('self_loop', 'item', 824)],
#   [('self_loop', 'user', 3645),
#    ('interested_in', 'category', 29),
#    ('category_of', 'item', 137),
#    ('self_loop', 'item', 137)],
#   [('self_loop', 'user', 3645),
#    ('interested_in', 'category', 29),
#    ('category_of', 'item', 131),
#    ('self_loop', 'item', 131)],
#   [('self_loop', 'user', 3645),
#    ('like', 'brand', 4),
#    ('belong_to', 'item', 195),
#    ('self_loop', 'item', 195)],
#   [('self_loop', 'user', 3645),
#    ('like', 'brand', 4),
#    ('self_loop', 'brand', 4),
#    ('belong_to', 'item', 195)],
#   [('self_loop', 'user', 3645),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 43),
#    ('self_loop', 'item', 43)],
#   [('self_loop', 'user', 3645),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 106),
#    ('self_loop', 'item', 106)],
#   [('self_loop', 'user', 3645),
#    ('like', 'brand', 31),
#    ('belong_to', 'item', 131),
#    ('self_loop', 'item', 131)],
#   [('self_loop', 'user', 3645),
#    ('like', 'brand', 31),
#    ('belong_to', 'item', 106),
#    ('self_loop', 'item', 106)],
#   [('self_loop', 'user', 10969),
#    ('interested_in', 'category', 0),
#    ('category_of', 'item', 801),
#    ('category_of', 'category', 2078)],
# ...
#   [1.0, 1.9976976, 1.6197814],
#   [1.0, 1.0023025, 1.9965246],
#   [1.0, 1.4351428, 2.0],
#   [1.0, 1.4334702, 1.7786186],
#   [1.0, 1.494529, 1.575454],
#   [1.0, 1.4698308, 1.9353478],
#   [1.8203717, 1.9742186, 1.9999772],
#   [1.8203717, 1.0220199, 1.9999993],
#   [1.1550341, 1.9993455, 2.0],
#   [1.1550341, 1.0006546, 1.999997],
#   [1.0245752, 1.969697, 1.9999995],
#   [1.0245752, 1.0303012, 1.9999958],
#   [1.0000113, 1.8778112, 2.0],
#   [1.0000113, 1.1221554, 1.9999985],
#   [1.0000077, 1.5503515, 2.0],
#   [1.0000077, 1.4496424, 2.0],
#   [1.9989752, 1.7031362, 1.9999013],
#   [1.9989752, 1.2921278, 1.9999864],
#   [1.00042, 1.9981799, 1.9999936],
#   [1.00042, 1.0014244, 1.9999928],
#   [1.0003237, 1.9976263, 1.9996222],
#   [1.0003237, 1.0013245, 2.0],
#   [1.0002205, 1.5778911, 2.0],
#   [1.0002205, 1.2878203, 2.0],
#   [1.000055, 1.6148202, 1.9988087],
#   [1.000055, 1.3384091, 1.9993412],
#   [1.895322, 1.9983095, 1.9999987],
#   [1.895322, 1.0015688, 1.9999986],
#   [1.104499, 1.9999986, 1.9999999],
#   [1.104499, 1.0000013, 2.0],
#   [1.0001767, 1.5338926, 2.0],
#   [1.0001767, 1.466104, 2.0],
#   [1.0000008, 1.999873, 2.0],
#   [1.0000008, 1.000127, 2.0],
#   [1.0000006, 1.9979804, 1.9999902],
#   [1.0000006, 1.0007118, 1.9999886],
#   [1.9999996, 2.0, 2.0],
#   [1.9999996, 1.0, 2.0],
#   [1.0000004, 2.0, 2.0],
#   [1.0000004, 1.0, 1.9942043],
#   [1.0, 1.8810264, 2.0],
#   [1.0, 1.0782497, 2.0],
#   [1.0, 1.960854, 2.0],
#   [1.0, 1.0347984, 2.0],
#   [1.0, 1.995409, 1.9999868],
#   [1.0, 1.0044034, 2.0],
#   [1.7229781, 1.9887809, 1.9999998],
#   [1.7229781, 1.0112185, 2.0],
#   [1.1859, 1.4947975, 1.9999971],
#   [1.1859, 1.3370478, 2.0],
#   [1.0875099, 1.949913, 2.0],
#   [1.0875099, 1.0492176, 2.0],
#   [1.0035132, 1.992835, 1.999991],
#   [1.0035132, 1.0068247, 1.999994],
#   [1.0000746, 1.9834621, 1.9998732],
#   [1.0000746, 1.016372, 1.999995],
#   [1.878865, 1.9615045, 1.955334],
#   [1.878865, 1.0384954, 1.9999995],
#   [1.1210773, 1.9240631, 2.0],
#   [1.1210773, 1.068822, 1.9999995],
#   [1.0000552, 2.0, 2.0],
#   [1.0000552, 1.0, 1.9999775],
#   [1.0000017, 1.9993756, 1.9999993],
#   [1.0, 1.2249669, 1.9997578],
#   [1.9962449, 1.8893609, 1.9999994],
#   [1.9962449, 1.0673668, 1.9999996],
#   [1.0037549, 1.9518435, 1.9999803],
#   [1.0037549, 1.0333256, 1.999966],
#   [1.0000001, 1.8730683, 1.7539601],
#   [1.0000001, 1.1121584, 1.9565704],
#   [1.0, 1.9996634, 1.8503594],
#   [1.0, 1.0003171, 2.0],
#   [1.0, 1.9987879, 1.7146027],
#   [1.0, 1.001212, 1.9222441],
#   ...]}

# %%
for path, probs in zip(results["paths"], results["probs"]):
    if path[-1][1] != "item":
        continue
    uid = path[0][2]
    # 2) Triming item which are assosiacted with user_rej_items        
    # if pid in user_rej_items: 
    #     continue  # Skip this item if it's in the user_rej_items list
    if uid not in pred_paths:
        continue
    pid = path[-1][2]
    if pid not in pred_paths[uid]:
        pred_paths[uid][pid] = []
    path_score = scores[uid][pid]
    path_prob = reduce(lambda x, y: x * y, probs)
    pred_paths[uid][pid].append((path_score, path_prob, path))

# %%
# 3) Pick best path for each user-product pair, also remove pid if it is in train set.
best_pred_paths = {}
for uid in pred_paths:
    train_pids = set(train_labels.get(uid, []))
    # if len(train_pids) == 0:
    #     continue
    best_pred_paths[uid] = []
    for pid in pred_paths[uid]:
        if pid in train_pids:
            continue
        # Get the path with highest probability
        sorted_path = sorted(pred_paths[uid][pid], key=lambda x: x[1], reverse=True)
        best_pred_paths[uid].append(sorted_path[0])

# path_patterns = {}
# for uid in best_pred_paths:
#     for path in best_pred_paths[uid]:
#         path_pattern = path[2]
#         pattern_key = ""
#         for node in path_pattern:
#             pattern_key += node[0] + "_" + node[1] + "-->"
#         path_patterns[pattern_key] = path_patterns.get(pattern_key, 0) + 1

# path_patterns

# %%
# filename = os.path.join(result_file_dir, "patterns.json")
# # json.dump(path_patterns, open(filename, "w"), indent=4)

# cold_start_users_path = os.path.join(dir_path, "cold_start_users.json")
# cold_start_users = json.load(open(cold_start_users_path, "r"))
# cold_start_users = set(cold_start_users["train"])

# cold_path_patterns = {}
# for uid in best_pred_paths:
#     if uid not in cold_start_users:
#         for path in best_pred_paths[uid]:
#             path_pattern = path[2]
#             pattern_key = ""
#             for node in path_pattern:
#                 pattern_key += node[0] + "_" + node[1] + "-->"
#             cold_path_patterns[pattern_key] = (
#                 cold_path_patterns.get(pattern_key, 0) + 1
#             )

# cold_path_patterns

# %%
filename = os.path.join(result_file_dir, "cold_patterns.json")
# json.dump(cold_path_patterns, open(filename, "w"), indent=4)

# computes the item distribution from train_labels
item_distribution = Counter()
for uid in train_labels:
    item_distribution.update(train_labels[uid])

filename = os.path.join(result_file_dir, "item_distribution.json")
# json.dump(item_distribution, open(filename, "w"), indent=4)

# 3) Compute top 10 recommended products for each user.
sort_by = "score"
pred_labels = {}
for uid in best_pred_paths:
    if sort_by == "score":
        sorted_path = sorted(
            best_pred_paths[uid], key=lambda x: (x[0], x[1]), reverse=True
        )
    elif sort_by == "prob":
        sorted_path = sorted(
            best_pred_paths[uid], key=lambda x: (x[1], x[0]), reverse=True
        )
#  16862: [3461, 1172, 1608, 1187, 1355, 17],
#  9571: [676, 5275, 1356, 197, 62, 87],
#  5479: [38, 676, 161],
#  6878: [43, 436, 572, 839, 443, 76, 212, 328, 469],
#  17343: [914, 839, 85, 172, 210, 1142, 1157, 3880],
#  7004: [381, 195, 1063, 3, 43, 3118, 1623],
#  15415: [5, 6, 53, 84, 31, 5539, 9615],
#  4291: [85, 381, 567, 1581, 1110, 1441, 37, 4861, 25, 680],
#  3391: [1453, 85, 161, 381, 2731, 5, 231, 91, 20],
#  19722: [43, 248, 695, 1062, 124, 2163, 4283],
#  20110: [56, 7231, 43, 442, 217, 51, 4291, 1515, 4324],
#  10600: [734, 676, 3114, 628, 438, 10935],
#  404: [725, 56, 1455, 7, 170, 1301, 1230, 9, 92, 412],
#  5280: [43, 106, 439, 1076, 131, 247, 1238, 1192, 177, 840],
#  7705: [43, 72, 37, 1188, 122, 68, 1187, 1571],
#  4636: [1455, 11939, 2313, 48, 684, 1254, 167, 26, 1155],
#  12012: [676, 247, 186, 1818, 55, 442, 2383, 4410, 2440],
#  16221: [7466, 43, 377, 11, 5, 3],
#  5228: [36, 562, 492, 167, 2, 9],
#  17116: [472, 56, 190, 441, 8504, 1362, 254, 149, 270],
#  14128: [8303, 978, 11, 1862, 43, 138, 4422, 1922, 23, 9],
#  6226: [1144, 921, 11, 1660, 1545, 7492, 23, 99, 85],
#  4457: [1835, 1733, 1927, 725, 43, 1688, 3, 10740, 2588, 55],
#  11579: [19, 18, 111, 328, 43, 676, 68, 415],
#  7531: [43, 1076, 1534, 5686, 1506, 107, 370, 386],
#  20648: [72, 381, 206, 19, 11912, 1210, 4484, 6899],
#  1472: [367, 907, 676, 780, 1796, 525, 55, 661, 2670],
#  8337: [2239, 15, 9, 353, 7, 23, 2822, 272],
#  16066: [247, 1062, 1453, 1231, 43, 36, 2579, 267, 3184],
#  12370: [219, 369, 885, 48, 156, 592, 1574, 218, 122],
#  12640: [161, 885, 552, 6650, 1030, 305, 15, 43],
#  8925: [1311, 2149, 1127, 442, 827, 284, 2831, 4410, 6552],
#  3521: [1757, 1146, 3174, 1144, 186, 1043, 195, 203, 1882, 1765],
#  3486: [36, 367, 85, 700, 874, 63, 82, 216],
#  ...}

# %%
test_labels
# Out:
# {5164: [2085],
#  1333: [10758],
#  12080: [9151],
#  867: [1643, 1811],
#  12887: [4919, 7614, 9578, 7623],
#  3563: [9918, 2171],
#  297: [6846],
#  22289: [9576],
#  6214: [10865],
#  21576: [1284],
#  378: [5630],
#  20047: [3541],
#  3167: [11369],
#  6045: [7186],
#  15355: [5486],
#  4492: [10371],
#  12566: [9063, 8923, 2171, 7309, 9706, 167, 8180],
#  12757: [1057],
#  21991: [6856],
#  3012: [2339],
#  5373: [4870],
#  4248: [2246],
#  1259: [4158],
#  4598: [6424],
#  7562: [503],
#  14357: [7182],
#  1749: [11153],
#  2189: [2910],
#  16766: [5845],
#  18384: [12005],
#  1005: [11586],
#  20135: [2325],
#  9841: [8407],
#  12552: [10907],
#  7344: [9617],
#  1063: [11133],
#  3645: [5603],
#  10969: [3200],
#  4887: [3637],
#  3606: [6299],
#  9079: [10772],
#  20406: [1901],
#  13371: [10640],
#  21617: [6021],
#  11703: [1430],
#  17322: [9523],
#  13036: [5112],
#  10612: [8486],
#  14620: [8374],
#  22019: [4807],
#  9033: [4165],
#  15205: [9614],
#  6756: [3266],
#  18137: [7689],
#  6400: [1975, 10969],
#  12153: [6378],
#  3648: [11632],
#  18831: [5467],
#  1187: [6408],
#  12497: [945],
#  17069: [3903],
#  10443: [4705, 7570],
#  21393: [2621],
#  13626: [2055],
#  2801: [2502],
#  19758: [7433],
#  1122: [6549],
#  21317: [11574],
#  13135: [978],
#  5897: [3627],
#  284: [217],
#  19628: [1811],
#  13253: [2246],
#  10547: [9600],
#  16431: [765, 6069],
#  16371: [4264, 7857, 9322],
#  17747: [8591],
#  4154: [6958],
#  17292: [7500],
#  19571: [3487],
#  9391: [3990],
#  9371: [7047],
#  19099: [1650, 7717, 1687, 11248, 11628, 4133, 7589, 8435],
#  8114: [8411],
#  20105: [8180],
#  5308: [6056],
#  17920: [10581],
#  12982: [2936],
#  3955: [6656],
#  19035: [7140],
#  2340: [1743],
#  21896: [10523, 7010],
#  3655: [11679],
#  5222: [10110, 2765, 3195],
#  5463: [3444],
#  20879: [7104, 10307, 5272, 4340, 709, 6800, 11290],
#  21786: [9064],
#  20156: [6704],
#  15911: [3606],
#  6031: [6709],
#  11802: [4468],
#  3016: [482],
#  5936: [10742],
#  7659: [6078, 1068],
#  7835: [6976],
#  12437: [6056],
#  1730: [3220],
#  10816: [11303],
#  6490: [2856, 10716],
#  12910: [3016],
#  21399: [9966],
#  21764: [3819],
#  14322: [452],
#  10248: [1584],
#  11739: [9079],
#  6245: [9241],
#  14861: [7200],
#  15081: [2907],
#  5738: [11726],
#  4254: [11535],
#  11827: [6921],
#  14167: [11293],
#  1890: [1646, 5247, 3503],
#  13911: [3870],
#  7950: [4595, 4125],
#  14162: [5973, 4205],
#  1858: [8727],
#  21685: [7857],
#  6844: [4199],
#  12739: [295],
#  15836: [1206],
#  21217: [4937],
#  16162: [10740],
#  22226: [6658],
#  12468: [6197],
#  8231: [9387],
#  9276: [10539],
#  10258: [10609],
#  11202: [6760],
#  22000: [2463],
#  100: [10827, 7733],
#  9446: [5062],
#  20145: [5307],
#  19117: [7303],
#  4316: [1882],
#  1080: [10357],
#  6074: [7187],
#  717: [992],
#  2276: [1702, 10110, 2171, 9238, 1658, 1848, 4613, 11592],
#  9617: [6803],
#  10267: [6911],
#  267: [5863],
#  17254: [6801, 6768, 9907],
#  997: [2993],
#  1655: [2054],
#  4003: [6510],
#  21838: [8453],
#  20545: [10037],
#  6063: [531],
#  16619: [4871],
#  805: [11588],
#  4645: [5589],
#  12201: [9859],
#  10494: [11783],
#  3710: [2448, 3453],
#  15345: [10036],
#  3835: [7233],
#  22288: [1634],
#  17138: [10523],
#  15250: [7459],
#  16555: [8889],
#  6528: [5807],
#  1383: [4125],
#  13552: [10582],
#  13472: [482],
#  14536: [9503],
#  19415: [3125],
#  22315: [2691, 10988],
#  19161: [6079],
#  7457: [3664],
#  1659: [11916],
#  6701: [8429],
#  14597: [3877],
#  18010: [3694],
#  15781: [2122],
#  4670: [4742],
#  14034: [8680],
#  18949: [6306],
#  9780: [8800],
#  8271: [10342],
#  10417: [7692],
#  15075: [2841],
#  15368: [8322],
#  6659: [10750, 7156, 9142, 4714, 1691],
#  17042: [8168],
#  16516: [6600],
#  14789: [11916],
#  6699: [11290],
#  7204: [723],
#  22045: [3601, 7075],
#  5004: [5533],
#  7125: [3666],
#  18143: [3301],
#  18671: [944],
#  13392: [8816],
#  3619: [9625],
#  14318: [6846, 9015, 9072, 5155],
#  6761: [5088],
#  391: [7690],
#  13620: [9033],
#  9041: [1731, 8716, 7487, 5062, 9884, 3363],
#  10209: [9311],
#  20340: [10748],
#  1626: [11441],
#  12444: [7566],
#  2964: [8614],
#  1915: [3456],
#  2904: [3363],
#  15889: [11119],
#  10000: [4647, 11148, 8488, 7433, 9966],
#  19190: [10594],
#  3406: [11406],
#  15721: [28],
#  5001: [5485],
#  14134: [10337],
#  5459: [6735, 9261, 5644],
#  18815: [812],
#  9096: [4354],
#  7872: [2856],
#  6631: [7361],
#  6525: [3843],
#  8848: [9847, 2031, 5325, 2205, 9953],
#  16366: [2433, 11687, 8917, 2733],
#  2350: [2313],
#  17943: [49],
#  16481: [1817],
#  2526: [1142],
#  18193: [3871],
#  9198: [9142, 9619],
#  14867: [11222, 5473],
#  21: [9903],
#  11467: [6650],
#  16803: [3616],
#  60: [3833],
#  11576: [3073],
#  9956: [2386, 4551, 10426],
#  22345: [3025],
#  423: [1347, 2528],
#  1287: [8762],
#  12432: [3110],
#  11615: [4166],
#  18073: [10165],
#  18983: [7032],
#  10360: [9626],
#  12250: [11365],
#  14684: [7443],
#  22: [10931],
#  19778: [1953],
#  10574: [6134],
#  17044: [4945],
#  569: [11323],
#  17703: [106],
#  4399: [6056],
#  8619: [8718],
#  13430: [1380],
#  6507: [1019],
#  14456: [724],
#  651: [903],
#  14408: [1927, 11840, 1172],
#  13566: [8184],
#  580: [539],
#  2165: [10871],
#  19772: [10206],
#  11658: [6308],
#  225: [4111],
#  10536: [2601],
#  20793: [7847],
#  2852: [1019],
#  35: [415],
#  9425: [9136],
#  8695: [8141],
#  4601: [1144],
#  2933: [11954],
#  9187: [8713],
#  20887: [11810],
#  20988: [8358],
#  2065: [5241],
#  13971: [2053],
#  15883: [11925],
#  13012: [5954],
#  4306: [747],
#  6725: [6709],
#  7443: [734],
#  17815: [9726, 9965],
#  5112: [6654],
#  18567: [4023],
#  5649: [341],
#  15959: [3754],
#  15282: [9380, 3629, 1172, 1568],
#  8165: [12071],
#  18056: [4186],
#  3400: [3202],
#  7654: [3417, 2833, 8940],
#  12294: [10945],
#  17723: [9966, 10730, 1975, 5973],
#  6752: [1895],
#  7183: [3405],
#  17097: [2171, 10730, 10841, 11148, 940],
#  16325: [11784],
#  22202: [6347],
#  3998: [762],
#  14321: [3952],
#  17459: [6965],
#  4562: [7094],
#  13127: [6069, 5850],
#  9698: [6317],
#  1121: [1068, 1399, 4540],
#  13916: [5601],
#  1821: [9487],
#  2395: [8962],
#  13738: [9522],
#  5215: [3113],
#  18947: [729],
#  573: [2652, 5878, 5161, 2166],
#  17038: [5105],
#  2690: [1702, 4945, 10078],
#  6229: [1188],
#  1217: [8109],
#  4271: [6730],
#  19209: [728],
#  5666: [6785],
#  2525: [642],
#  6907: [9425],
#  22129: [7543],
#  8857: [10422],
#  3960: [1667],
#  14102: [9474, 12071, 10941],
#  8279: [8137, 6465, 11810],
#  16440: [11469],
#  16735: [5552],
#  16922: [7799],
#  3999: [442],
#  10683: [3124],
#  695: [9936],
#  16212: [386],
#  8835: [10382],
#  4923: [10976],
#  5966: [3197],
#  15906: [9936],
#  9360: [10790],
#  9600: [1184],
#  12255: [2171, 3793, 7186, 8980, 10841, 10969, 8488, 4064, 1517, 3262, 2345],
#  2973: [7547],
#  1481: [2559],
#  8556: [6151],
#  1929: [10843, 167, 6306],
#  2649: [2183],
#  19255: [4133],
#  5248: [4246],
#  3365: [8967],
#  11478: [7500],
#  9520: [5514],
#  15785: [7817],
#  13891: [7309],
#  2987: [10931],
#  7220: [10128],
#  3628: [8488, 552],
#  12219: [186],
#  21192: [6460],
#  21613: [10169],
#  3399: [7403],
#  10281: [6755],
#  21483: [12026],
#  4239: [758],
#  13473: [3798],
#  1380: [684],
#  365: [7166],
#  1495: [1339],
#  15953: [8442],
#  12933: [5288],
#  4436: [5344, 6836, 9389, 3914, 1222, 796],
#  11891: [4796],
#  12694: [2276],
#  9593: [10259],
#  2698: [7585],
#  17082: [2239],
#  19900: [1511],
#  16007: [10833],
#  15098: [10941],
#  3602: [3373],
#  9022: [8966],
#  10645: [2313],
#  9802: [6931],
#  18254: [3335],
#  3409: [1199],
#  4221: [466],
#  8151: [11781],
#  2152: [11414],
#  9689: [5956],
#  19599: [5973, 7493, 4041, 10398, 552, 4089],
#  16388: [3314],
#  15284: [1204],
#  2470: [335],
#  20657: [5500],
#  19182: [2054],
#  7582: [3000],
#  7550: [11614],
#  21732: [6001],
#  4647: [10000],
#  14298: [237],
#  1879: [6347, 1251],
#  14164: [862],
#  6951: [4590],
#  9440: [6052, 2213],
#  12740: [1339],
#  5015: [1333],
#  14101: [6506],
#  3252: [11184],
#  16715: [5410],
#  21444: [2679],
#  1162: [7669, 1578, 3489],
#  14365: [3790],
#  14423: [9700],
#  19743: [2401, 3262, 8745],
#  17479: [8961],
#  17648: [4224],
#  9965: [9420],
#  4997: [10485],
#  1874: [8308],
#  20022: [6932],
#  4371: [133],
#  20544: [8962],
#  6668: [5018],
#  10700: [642],
#  10006: [4809],
#  8395: [8354],
#  16548: [7900],
#  1503: [4872],
#  9835: [6549],
#  9642: [2054],
#  7357: [5687],
#  3239: [5256],
#  9529: [4017],
#  1954: [9213],
#  19066: [1917],
#  13600: [8963],
#  12638: [11819],
#  1853: [1987],
#  15324: [2959],
#  7580: [4647],
#  18695: [8582],
#  8828: [8146],
#  14487: [3592],
#  1004: [6672],
#  19482: [8709],
#  1932: [9322],
#  15395: [10299],
#  2185: [6347],
#  10414: [9007],
#  20217: [6777],
#  5028: [1515, 8120, 10424, 2230, 7138],
#  6011: [2578],
#  8913: [10142],
#  4452: [5525],
#  10476: [8488, 2403, 186, 10941, 7493, 5062, 9368],
#  1334: [3110],
#  3862: [11096],
#  3413: [3588],
#  680: [571],
#  2634: [754],
#  19404: [8344, 5002, 10398, 8340, 10730, 11391],
#  20992: [3124],
#  13412: [12044],
#  20984: [91],
#  9404: [7614],
#  14414: [4396],
#  5696: [11990],
#  5294: [11764],
#  15490: [9400],
#  9792: [1240],
#  1945: [3709],
#  10276: [1155],
#  1593: [9853, 7361],
#  78: [9706, 10172, 1975, 10941],
#  18916: [166],
#  1434: [7953],
#  1247: [11614],
#  12691: [11066],
#  19958: [4742, 4064],
#  2173: [8656],
#  2022: [470],
#  8202: [1602],
#  21708: [1362],
#  15251: [1873],
#  19228: [8485],
#  16587: [9615],
#  17745: [7614],
#  11562: [8050],
#  4878: [10834],
#  10124: [6306, 8340],
#  2666: [829],
#  17675: [5132],
#  15532: [6960],
#  20012: [3666],
#  6751: [9862],
#  1883: [9974],
#  1300: [639],
#  15315: [8636],
#  21823: [9907],
#  7190: [7732],
#  18584: [7290],
#  6224: [4590],
#  19185: [9380],
#  14285: [7345, 3240, 1380],
#  426: [8999],
#  17926: [728],
#  2477: [2566, 11516],
#  8761: [7727],
#  12448: [9529],
#  5944: [4592],
#  1407: [10191],
#  14224: [7259],
#  6183: [7489],
#  16522: [7078, 9315],
#  3370: [10969, 6465, 7493, 3795, 4150, 1197, 10402, 2765, 8765],
#  8175: [7113],
#  11245: [442],
#  5016: [7902],
#  6677: [1112],
#  6349: [5952],
#  4825: [10320, 2173],
#  12907: [6370],
#  11578: [8343],
#  20467: [5511],
#  9783: [4727],
#  10767: [7126],
#  11519: [2295],
#  10575: [10573],
#  16593: [10337],
#  9847: [14, 3914],
#  6075: [7397],
#  1255: [10245],
#  803: [1930, 11216, 156, 159, 4997, 7963],
#  21390: [10152],
#  14190: [10564],
#  18940: [4397, 381],
#  13278: [10244],
#  11227: [11172],
#  6790: [1986],
#  22219: [2136],
#  198: [3769],
#  10426: [11369, 303, 11402],
#  13198: [7452],
#  8127: [11581],
#  17197: [712, 11559],
#  5534: [11406],
#  2536: [9666],
#  6185: [3694],
#  17450: [9101, 3503],
#  13628: [8733],
#  16605: [11737, 921, 2213, 6052, 9315, 11736],
#  11307: [10271],
#  13025: [11267],
#  10712: [3016],
#  5184: [2850],
#  10141: [11446],
#  3556: [10500],
#  15259: [3186, 7817],
#  19492: [8583],
#  14354: [5344],
#  6376: [369],
#  16642: [224],
#  12345: [3668],
#  14380: [4251],
#  20366: [7751],
#  11594: [11296, 11115, 2691, 7631, 12029],
#  7955: [883],
#  13844: [1990],
#  3022: [4341],
#  14096: [4082],
#  13874: [2109],
#  14999: [3414],
#  681: [7770],
#  6839: [1146],
#  4282: [1231],
#  15771: [93],
#  18355: [1455],
#  18342: [1533, 6731, 5017],
#  3537: [9537],
#  20138: [5486],
#  6290: [3474],
#  6357: [12038],
#  8406: [1098],
#  4524: [1810],
#  9439: [2313, 8340, 8811, 9665],
#  15242: [5652],
#  22247: [10178],
#  19539: [4942],
#  9358: [7917],
#  19788: [8164],
#  5967: [9409],
#  11640: [1997],
#  20057: [10273],
#  5700: [2691],
#  3256: [2907],
#  11439: [6973, 11587, 10432, 2605, 8159, 3556],
#  11956: [7689],
#  21237: [8059],
#  1620: [4352],
#  9614: [10438],
#  15904: [8576],
#  641: [11840],
#  11743: [8313, 5247, 7348, 5973, 8488, 4089, 11736],
#  5961: [9375],
#  2570: [503],
#  8893: [7852, 2332, 8101],
#  14551: [92, 8100, 276, 1875, 5843],
#  19910: [2759],
#  8633: [1646, 9063],
#  14289: [9221],
#  17902: [9802],
#  11391: [8338],
#  13126: [3905],
#  16823: [266],
#  555: [7403],
#  13584: [1559],
#  10527: [3144],
#  11179: [1646, 3629],
#  14631: [8850],
#  11943: [7246],
#  1934: [6625],
#  6083: [2652, 4190],
#  6838: [6046],
#  21793: [714],
#  13735: [729],
#  20210: [8000, 7617],
#  1630: [1835],
#  4730: [7505],
#  10958: [1581],
#  7233: [11737],
#  20962: [3435],
#  7408: [1615],
#  16097: [9534],
#  18804: [985],
#  2211: [6205],
#  9575: [1653],
#  14115: [4199],
#  21799: [2691],
#  10711: [5277],
#  15121: [2031],
#  18565: [10031],
#  8546: [9936],
#  12030: [7535],
#  14692: [2369],
#  19460: [9446],
#  14172: [538],
#  10715: [5128],
#  15209: [7572],
#  17522: [1901],
#  3978: [2403, 5973, 11736, 8162, 167, 9063, 10841, 11810],
#  3917: [7267],
#  15962: [5238],
#  710: [11572],
#  19901: [372],
#  5431: [1346],
#  6497: [11587],
#  909: [11382],
#  20633: [11937],
#  21241: [1865, 1905],
#  7476: [9842],
#  2565: [8795],
#  17733: [1011],
#  21855: [6659],
#  1666: [4103],
#  7707: [3001],
#  4773: [1455],
#  7624: [4136],
#  7842: [1487],
#  13869: [7975],
#  15012: [6347],
#  2023: [6541],
#  22349: [11009, 5917],
#  13910: [1011],
#  3058: [8557],
#  1440: [5564],
#  19326: [10841, 8923, 10110, 5002, 10398, 4089],
#  8235: [7733, 186],
#  9828: [1835],
#  10295: [9568],
#  14556: [6926],
#  18854: [7047],
#  13390: [10442],
#  13013: [11093],
#  8045: [3444],
#  12885: [6348],
#  18559: [4679],
#  10082: [9776],
#  5039: [8621],
#  21908: [1202],
#  7864: [4549],
#  15151: [179],
#  18397: [1669],
#  21990: [9474],
#  6698: [6579],
#  20883: [3314],
#  13091: [6594],
#  14278: [471],
#  4443: [1013],
#  14553: [1653],
#  13535: [11305],
#  12280: [6129],
#  15320: [8127],
#  5956: [11949],
#  18847: [8373, 5446],
#  8886: [7877],
#  1074: [10240],
#  3070: [2186],
#  17855: [2311],
#  6564: [1059],
#  17134: [7138],
#  216: [5486, 10572],
#  11075: [2418],
#  10743: [613],
#  12808: [1199],
#  20139: [8033],
#  1828: [2267],
#  2547: [9104],
#  22164: [989],
#  9344: [7249],
#  14418: [442],
#  3887: [5079],
#  18525: [2459],
#  6697: [5603, 7145],
#  14649: [2961],
#  1008: [149],
#  19865: [9192],
#  8346: [10917],
#  14688: [1001],
#  16711: [8196],
#  698: [11517],
#  14185: [4932],
#  14384: [6931],
#  19773: [8881],
#  12972: [7335],
#  16119: [3799],
#  17761: [9029],
#  12361: [3534],
#  8163: [8513],
#  21693: [10354],
#  20688: [10699],
#  631: [9841, 11153, 10337, 7233],
#  13368: [2566],
#  11327: [10586, 8134, 6646, 8088],
#  17909: [8973, 2234],
#  4815: [220],
#  21964: [9393],
#  8789: [3335],
#  14270: [7942, 10019],
#  10504: [824],
#  17304: [8821],
#  311: [7112,
#   4985,
#   1750,
#   7434,
#   227,
#   10005,
#   2462,
#   2709,
#   10630,
#   1600,
#   10366,
#   9651,
#   4630,
#   9331,
#   8119],
#  13149: [302, 8772, 3515],
#  7350: [10941, 2660],
#  8109: [10475],
#  12061: [7545],
#  213: [6421, 8354],
#  10644: [2869, 5211, 8666, 12002],
#  10469: [8262],
#  11608: [4038],
#  6470: [3360],
#  12241: [5021, 10716, 7264],
#  15141: [9158],
#  12538: [3966],
#  6404: [3182],
#  8370: [2529],
#  1132: [1629, 6417, 1347],
#  18529: [10402],
#  7490: [3773, 11177, 9768, 8201, 10386, 7743, 4864, 2769, 11592],
#  17471: [4150, 55, 8354],
#  12220: [5336],
#  15818: [11430],
#  4168: [3191],
#  12981: [3927],
#  17239: [382],
#  20411: [14],
#  3590: [6823],
#  8885: [11346],
#  10796: [5500],
#  17879: [6989],
#  3200: [4682],
#  754: [10620],
#  18198: [6751],
#  15076: [10422, 10182, 2468],
#  4680: [1994],
#  165: [4945, 1291],
#  17966: [6777],
#  7948: [1926],
#  20277: [4943],
#  20491: [10538],
#  18392: [7438, 10841, 7493, 3461, 5002],
#  1905: [235],
#  2155: [3892],
#  4429: [10234],
#  13209: [9065, 10077],
#  7727: [8541, 3743, 1963, 3259, 4611],
#  4580: [10744],
#  564: [7978],
#  22356: [11726],
#  20904: [10938],
#  14796: [10283],
#  1166: [5200],
#  11611: [1379],
#  11837: [8624],
#  19021: [10048, 10398, 765, 4089, 1927, 3461],
#  20799: [200],
#  1576: [9356],
#  8046: [6514],
#  11593: [2858],
#  179: [6255],
#  19134: [5018],
#  4052: [5181],
#  16215: [9213],
#  8049: [2495],
#  1681: [5894],
#  10682: [5519, 445, 10172],
#  14706: [2733],
#  18920: [8880],
#  12607: [9866],
#  14512: [10831, 5878, 1013],
#  16608: [10110, 765, 9966, 2171, 4647, 11002, 307, 7493, 2180, 5247, 10398],
#  5714: [10226],
#  1966: [5803],
#  6126: [5629, 7078, 415],
#  18748: [3827],
#  18071: [10157],
#  6378: [6306],
#  2339: [10665],
#  4377: [7182],
#  12089: [7871],
#  20934: [10688],
#  12244: [1659],
#  17532: [11622],
#  7924: [2424],
#  16142: [8569],
#  8697: [11736, 2295, 11833, 8662, 5062],
#  22053: [1737],
#  14529: [695],
#  17014: [3487],
#  2688: [8318],
#  18499: [7488],
#  21212: [10522],
#  20605: [9337],
#  15212: [4064, 1172, 8980],
#  6610: [7824],
#  9707: [6592],
#  12270: [5639],
#  13806: [3989],
#  7399: [11285, 6397, 7569, 3195, 7493, 10958, 9711, 10110, 9630, 4089],
#  541: [6408],
#  2448: [6820],
#  13787: [12026, 10402],
#  8864: [3585],
#  5454: [1380],
#  1041: [10936],
#  3069: [11370],
#  17738: [1251, 55],
#  16230: [10986],
#  5904: [3538],
#  13827: [412],
#  8391: [4384],
#  8986: [3052],
#  7577: [2691],
#  889: [3325],
#  20734: [10491, 11014, 7752],
#  18626: [11014, 10974, 10001, 9573],
#  14934: [4006],
#  5344: [3603],
#  7472: [3856],
#  17271: [4809],
#  20223: [2380],
#  3460: [11398],
#  18808: [2403, 1975, 7311, 765, 6465],
#  6162: [4125],
#  4368: [1506],
#  10908: [8488],
#  14610: [3621],
#  9970: [1466],
#  13467: [7186, 8032, 4740, 4124, 5501, 9380, 9342, 11153, 3525, 10851, 8795],
#  14385: [4590],
#  8464: [3461],
#  14248: [9016],
#  15765: [11427],
#  1168: [7971],
#  14113: [11338],
#  21465: [1857],
#  20959: [5062, 9841, 7122],
#  12371: [11726],
#  883: [2403],
#  17487: [4605],
#  20058: [3132],
#  2681: [7553],
#  5198: [6617],
#  6667: [6233],
#  19595: [58],
#  14176: [6349],
#  17201: [3651],
#  1263: [9132],
#  16958: [8468],
#  5435: [9915],
#  9836: [6056],
#  16557: [2782, 7385, 6960, 11736],
#  19557: [7752],
#  13170: [8052],
#  3438: [10716, 7539, 3363, 1688, 2588, 10307, 7738],
#  1582: [8866],
#  20160: [3598],
#  10278: [2214],
#  12960: [9358],
#  9976: [201],
#  6945: [9311],
#  19665: [4679, 11581],
#  775: [6021],
#  9628: [5222],
#  14889: [11607, 7204, 5617, 11406, 4525, 10493, 10776],
#  10190: [2920],
#  15363: [8977],
#  7871: [11465],
#  0: [6212],
#  14058: [5963],
#  2089: [1394, 8281],
#  11911: [10933],
#  2032: [10794],
#  19045: [8889],
#  21132: [7118],
#  18233: [3444],
#  20255: [620, 1402, 6783],
#  5020: [6008],
#  11614: [3444],
#  16391: [10545],
#  20365: [9833, 9374, 305, 10329],
#  20418: [11556],
#  22362: [11715],
#  18119: [4041],
#  20416: [11736],
#  2028: [6728],
#  12630: [11698],
#  3587: [6958],
#  18317: [6161],
#  11660: [2403, 3853, 48, 10110, 4613, 10941, 5814, 10877, 1658, 9063, 10665],
#  10705: [5114, 3419, 4540],
#  17019: [8358],
#  20601: [3546],
#  15854: [5404, 9697],
#  18608: [9472],
#  3639: [10337],
#  9651: [5831],
#  20575: [11433],
#  19689: [5226],
#  4044: [4671],
#  14972: [11494],
#  12821: [1043, 1517, 6215],
#  20462: [2732],
#  17005: [9353],
#  18386: [4314],
#  6433: [11075],
#  18308: [9415],
#  16862: [8765],
#  9571: [4150, 768],
#  5479: [6002],
#  6878: [8268],
#  17343: [4518],
#  7004: [2295],
#  15415: [11672],
#  4291: [4038],
#  3391: [4496],
#  19722: [9365],
#  20110: [56],
#  10600: [2297],
#  404: [1282, 1315, 5333, 4111],
#  5280: [9896],
#  7705: [6191],
#  4636: [11939],
#  12012: [10329, 7733],
#  16221: [7466],
#  5228: [8905],
#  17116: [8494],
#  14128: [8303],
#  6226: [8050],
#  4457: [6001],
#  11579: [8088],
#  7531: [2301],
#  20648: [10481],
#  1472: [5076],
#  8337: [10403, 2874],
#  16066: [9258],
#  12370: [9213],
#  12640: [11075, 7385, 362],
#  8925: [3461],
#  3521: [2365],
#  3486: [10523],
#  ...}

# %%
topk_matches = pred_labels
test_user_products = test_labels
train_user_products = train_labels
use_wandb = False
dir_path = config.processed_data_dir
result_file_dir =result_file_dir
min_items=10
compute_all=True
k = 10

# %%
user_relations = Counter()
kg = load_kg(dir_path, set_name="test")
for uid, relations in kg.G["user"].items():
    for entities in relations.values():
        user_relations[uid] += len(entities)
        
invalid_users = []

# Metrics for all users
user_metrics = dict()

# Compute metrics
precisions, recalls, ndcgs, hits, hits_at_1, hits_at_3, hits_at_5 = ([], [], [], [], [], [], [], )
(precisions_all, recalls_all, ndcgs_all, hits_all, hits_at_1_all, hits_at_3_all, hits_at_5_all, ) = ([], [], [], [], [], [], [])
test_user_idxs = list(test_user_products.keys())

# %%
for uid in test_user_idxs:
    is_invalid = False
    if uid not in topk_matches or len(topk_matches[uid]) < min_items:
        invalid_users.append(uid)
        is_invalid = True
    pred_list, rel_set = topk_matches.get(uid, []), test_user_products[uid]
    nb_train = len(train_user_products.get(uid, []))
    if len(pred_list) == 0:
        ndcgs_all.append(0.0)
        recalls_all.append(0.0)
        precisions_all.append(0.0)
        hits_all.append(0.0)
        hits_at_1_all.append(0.0)
        hits_at_3_all.append(0.0)
        hits_at_5_all.append(0.0)
        continue

    if is_invalid == False:
        dcg = 0.0
        hit_num = 0.0
        hit_at_1 = 0.0
        hit_at_3 = 0.0
        hit_at_5 = 0.0

        for i in range(len(pred_list)):
            if pred_list[i] in rel_set:
                dcg += 1.0 / (log(i + 2) / log(2))
                hit_num += 1
                if i < 1:
                    hit_at_1 += 1
                if i < 3:
                    hit_at_3 += 1
                if i < 5:
                    hit_at_5 += 1
        # idcg
        idcg = 0.0
        for i in range(min(len(rel_set), k)):
            idcg += 1.0 / (log(i + 2) / log(2))
        ndcg = dcg / idcg
        recall = hit_num / len(rel_set)
        precision = hit_num / k
        hit = 1.0 if hit_num > 0.0 else 0.0
        hit_at_1 = 1.0 if hit_at_1 > 0.0 else 0.0
        hit_at_3 = 1.0 if hit_at_3 > 0.0 else 0.0
        hit_at_5 = 1.0 if hit_at_5 > 0.0 else 0.0

        ndcgs.append(ndcg)
        recalls.append(recall)
        precisions.append(precision)
        hits.append(hit)
        hits_at_1.append(hit_at_1)
        hits_at_3.append(hit_at_3)
        hits_at_5.append(hit_at_5)

        ndcgs_all.append(ndcg)
        recalls_all.append(recall)
        precisions_all.append(precision)
        hits_all.append(hit)
        hits_at_1_all.append(hit_at_1)
        hits_at_3_all.append(hit_at_3)
        hits_at_5_all.append(hit_at_5)
            
    elif compute_all == True:
        dcg_all = 0.0
        hit_num_all = 0.0
        hit_at_1_all = 0.0
        hit_at_3_all = 0.0
        hit_at_5_all = 0.0
        for i in range(len(pred_list)):
            if pred_list[i] in rel_set:
                dcg_all += 1.0 / (log(i + 2) / log(2))
                hit_num_all += 1
                if i < 1:
                    hit_at_1_all += 1
                if i < 3:
                    hit_at_3_all += 1
                if i < 5:
                    hit_at_5_all += 1
        # idcg
        idcg_all = 0.0
        for i in range(min(len(rel_set), k)):
            idcg_all += 1.0 / (log(i + 2) / log(2))
        ndcg_all = dcg_all / idcg_all
        recall_all = hit_num_all / len(rel_set)
        precision_all = hit_num_all / k
        hit_all = 1.0 if hit_num_all > 0.0 else 0.0
        hit_at_1_all = 1.0 if hit_at_1_all > 0.0 else 0.0
        hit_at_3_all = 1.0 if hit_at_3_all > 0.0 else 0.0
        hit_at_5_all = 1.0 if hit_at_5_all > 0.0 else 0.0
        ndcgs_all.append(ndcg_all)
        recalls_all.append(recall_all)
        precisions_all.append(precision_all)
        hits_all.append(hit_all)
        hits_at_1_all.append(hit_at_1_all)
        hits_at_3_all.append(hit_at_3_all)
        hits_at_5_all.append(hit_at_5_all)
        
    else:
        ndcgs_all.append(0.0)
        recalls_all.append(0.0)
        precisions_all.append(0.0)
        hits_all.append(0.0)
        hits_at_1_all.append(0.0)
        hits_at_3_all.append(0.0)
        hits_at_5_all.append(0.0)
        

    user_metrics[uid] = {
        "ndcg": ndcgs_all[-1] * 100,
        "recall": recalls_all[-1] * 100,
        "hit": hits_all[-1] * 100,
        "precision": precisions_all[-1] * 100,
        "predictions": pred_list,
        "nb_train": nb_train,
        "nb_relations": user_relations[uid],
    }

    # break

# %%
avg_precision = np.mean(precisions) * 100
avg_recall = np.mean(recalls) * 100
avg_ndcg = np.mean(ndcgs) * 100
avg_hit = np.mean(hits) * 100
avg_hit_at_1 = np.mean(hits_at_1) * 100
avg_hit_at_3 = np.mean(hits_at_3) * 100
avg_hit_at_5 = np.mean(hits_at_5) * 100

avg_precision_all = np.mean(precisions_all) * 100
avg_recall_all = np.mean(recalls_all) * 100
avg_ndcg_all = np.mean(ndcgs_all) * 100
avg_hit_all = np.mean(hits_all) * 100
avg_hit_at_1_all = np.mean(hits_at_1_all) * 100
avg_hit_at_3_all = np.mean(hits_at_3_all) * 100
avg_hit_at_5_all = np.mean(hits_at_5_all) * 100

print(
    "NDCG={:.3f} |  Recall={:.3f} | HR={:.3f} | Precision={:.3f} | HR@1={:.3f} | HR@3={:.3f} | HR@5={:.3f} | Computed for all users.\n".format(
        avg_ndcg_all,
        avg_recall_all,
        avg_hit_all,
        avg_precision_all,
        avg_hit_at_1_all,
        avg_hit_at_3_all,
        avg_hit_at_5_all,
    )
)
# Out:
# NDCG=3.459 |  Recall=6.875 | HR=6.997 | Precision=0.700 | HR@1=1.169 | HR@3=2.584 | HR@5=3.884 | Computed for all users.

# %%
# # from test_agent import evaluate

# use_wandb = False

# evaluate(
#     pred_labels,
#     test_labels,
#     train_labels,
#     use_wandb,
#     config.processed_data_dir,
#     result_file_dir=result_file_dir,
#     min_items=10,
#     compute_all=True,
# )
